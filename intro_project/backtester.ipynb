# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from simulation import *
from RegressionTrader import *
from Stock4Trader import *

# %%
train = pd.read_csv("train_intro.csv", index_col = 0)
train.head()
# Out:
#     Stock1   Stock2   Stock3   Stock4  Stock1_Delay  Stock2_Delay  \
# 0  1479.36  1088.26  1545.61  1304.27       1481.40       1094.60
# 1  1479.33  1087.03  1544.94  1305.82       1479.36       1088.26
# 2  1479.72  1087.16  1543.55  1287.43       1479.33       1087.03
# 3  1477.47  1077.92  1545.35  1193.67       1479.72       1087.16
# 4  1474.91  1076.45  1545.01  1296.92       1477.47       1077.92
#
#    Stock3_Delay  Stock4_Delay
# 0       1546.06       1347.49
# 1       1545.61       1304.27
# 2       1544.94       1305.82
# 3       1543.55       1287.43
# 4       1545.35       1193.67

# %%
trader = Stock4Trader()
game = Game(trader, train)
results = game.run_game([])
results.history
# Out:
# Buying Stock4 at time 2 with 466.0 shares
# Buying Stock4 at time 3 with 502.0 shares
# Buying Stock4 at time 4 with -463.0 shares
# Buying Stock4 at time 5 with -473.0 shares
# Buying Stock4 at time 6 with -480.0 shares
# Buying Stock4 at time 7 with -490.0 shares
# Buying Stock4 at time 8 with -536.0 shares
# Buying Stock4 at time 9 with 556.0 shares
# Buying Stock4 at time 10 with -534.0 shares
# Buying Stock4 at time 11 with -547.0 shares
# Buying Stock4 at time 12 with 566.0 shares
# Buying Stock4 at time 13 with 536.0 shares
# Buying Stock4 at time 14 with 534.0 shares
# Buying Stock4 at time 15 with 524.0 shares
# Buying Stock4 at time 16 with 522.0 shares
# Buying Stock4 at time 17 with 515.0 shares
# Buying Stock4 at time 18 with -519.0 shares
# Buying Stock4 at time 19 with 736.0 shares
# Buying Stock4 at time 20 with 725.0 shares
# Buying Stock4 at time 21 with 710.0 shares
# Buying Stock4 at time 22 with 689.0 shares
# Buying Stock4 at time 23 with -654.0 shares
# Buying Stock4 at time 24 with 665.0 shares
# Buying Stock4 at time 25 with -604.0 shares
# Buying Stock4 at time 26 with 661.0 shares
# Buying Stock4 at time 27 with -657.0 shares
# Buying Stock4 at time 28 with -681.0 shares
# Buying Stock4 at time 29 with 723.0 shares
# Buying Stock4 at time 30 with -734.0 shares
# Buying Stock4 at time 31 with 796.0 shares
# Buying Stock4 at time 32 with 699.0 shares
# Buying Stock4 at time 33 with -662.0 shares
# Buying Stock4 at time 34 with 668.0 shares
# Buying Stock4 at time 35 with 655.0 shares
# Buying Stock4 at time 36 with 654.0 shares
# Buying Stock4 at time 37 with -645.0 shares
# Buying Stock4 at time 38 with 664.0 shares
# Buying Stock4 at time 39 with 660.0 shares
# Buying Stock4 at time 40 with 546.0 shares
# Buying Stock4 at time 41 with -533.0 shares
# Buying Stock4 at time 42 with 529.0 shares
# Buying Stock4 at time 43 with 509.0 shares
# Buying Stock4 at time 44 with -502.0 shares
# Buying Stock4 at time 45 with -499.0 shares
# Buying Stock4 at time 46 with 522.0 shares
# Buying Stock4 at time 47 with 474.0 shares
# Buying Stock4 at time 48 with -412.0 shares
# Buying Stock4 at time 49 with 398.0 shares
# Buying Stock4 at time 50 with -349.0 shares
# Buying Stock4 at time 51 with 362.0 shares
# Buying Stock4 at time 52 with 359.0 shares
# Buying Stock4 at time 53 with 370.0 shares
# Buying Stock4 at time 54 with -349.0 shares
# Buying Stock4 at time 55 with 357.0 shares
# Buying Stock4 at time 56 with -318.0 shares
# Buying Stock4 at time 57 with -314.0 shares
# Buying Stock4 at time 58 with 315.0 shares
# Buying Stock4 at time 59 with -304.0 shares
# Buying Stock4 at time 60 with -315.0 shares
# Buying Stock4 at time 61 with 345.0 shares
# Buying Stock4 at time 62 with 333.0 shares
# Buying Stock4 at time 63 with 305.0 shares
# Buying Stock4 at time 64 with -283.0 shares
# Buying Stock4 at time 65 with -311.0 shares
# Buying Stock4 at time 66 with -324.0 shares
# Buying Stock4 at time 67 with 336.0 shares
# Buying Stock4 at time 68 with -309.0 shares
# Buying Stock4 at time 69 with -338.0 shares
# Buying Stock4 at time 70 with -366.0 shares
# Buying Stock4 at time 71 with -377.0 shares
# Buying Stock4 at time 72 with -382.0 shares
# Buying Stock4 at time 73 with -390.0 shares
# Buying Stock4 at time 74 with -396.0 shares
# Buying Stock4 at time 75 with -428.0 shares
# Buying Stock4 at time 76 with 446.0 shares
# Buying Stock4 at time 77 with 438.0 shares
# Buying Stock4 at time 78 with -413.0 shares
# Buying Stock4 at time 79 with -415.0 shares
# Buying Stock4 at time 80 with 460.0 shares
# Buying Stock4 at time 81 with -380.0 shares
# Buying Stock4 at time 82 with 375.0 shares
# Buying Stock4 at time 83 with 325.0 shares
# Buying Stock4 at time 84 with 313.0 shares
# Buying Stock4 at time 85 with 299.0 shares
# Buying Stock4 at time 86 with 287.0 shares
# Buying Stock4 at time 87 with -288.0 shares
# Buying Stock4 at time 88 with -293.0 shares
# Buying Stock4 at time 89 with -290.0 shares
# Buying Stock4 at time 90 with 300.0 shares
# Buying Stock4 at time 91 with -298.0 shares
# Buying Stock4 at time 92 with 325.0 shares
# Buying Stock4 at time 93 with -291.0 shares
# Buying Stock4 at time 94 with -293.0 shares
# Buying Stock4 at time 95 with -301.0 shares
# Buying Stock4 at time 96 with -308.0 shares
# Buying Stock4 at time 97 with 314.0 shares
# Buying Stock4 at time 98 with 297.0 shares
# Buying Stock4 at time 99 with 284.0 shares
# Buying Stock4 at time 100 with 286.0 shares
# Buying Stock4 at time 101 with -282.0 shares
# Buying Stock4 at time 102 with -287.0 shares
# Buying Stock4 at time 103 with -293.0 shares
# Buying Stock4 at time 104 with 303.0 shares
# Buying Stock4 at time 105 with 282.0 shares
# Buying Stock4 at time 106 with -275.0 shares
# Buying Stock4 at time 107 with -285.0 shares
# Buying Stock4 at time 108 with 317.0 shares
# Buying Stock4 at time 109 with -290.0 shares
# Buying Stock4 at time 110 with -304.0 shares
# Buying Stock4 at time 111 with 323.0 shares
# Buying Stock4 at time 112 with 301.0 shares
# Buying Stock4 at time 113 with 287.0 shares
# Buying Stock4 at time 114 with 270.0 shares
# Buying Stock4 at time 115 with -275.0 shares
# Buying Stock4 at time 116 with 289.0 shares
# Buying Stock4 at time 117 with 283.0 shares
# Buying Stock4 at time 118 with -278.0 shares
# Buying Stock4 at time 119 with 297.0 shares
# Buying Stock4 at time 120 with -253.0 shares
# Buying Stock4 at time 121 with 259.0 shares
# Buying Stock4 at time 122 with -260.0 shares
# Buying Stock4 at time 123 with 288.0 shares
# Buying Stock4 at time 124 with -258.0 shares
# Buying Stock4 at time 125 with -280.0 shares
# Buying Stock4 at time 126 with 310.0 shares
# Buying Stock4 at time 127 with -298.0 shares
# Buying Stock4 at time 128 with -315.0 shares
# Buying Stock4 at time 129 with -313.0 shares
# Buying Stock4 at time 130 with -307.0 shares
# Buying Stock4 at time 131 with -318.0 shares
# Buying Stock4 at time 132 with -317.0 shares
# Buying Stock4 at time 133 with 336.0 shares
# Buying Stock4 at time 134 with -328.0 shares
# Buying Stock4 at time 135 with 332.0 shares
# Buying Stock4 at time 136 with 318.0 shares
# Buying Stock4 at time 137 with -315.0 shares
# Buying Stock4 at time 138 with -315.0 shares
# Buying Stock4 at time 139 with -344.0 shares
# Buying Stock4 at time 140 with -348.0 shares
# Buying Stock4 at time 141 with -362.0 shares
# Buying Stock4 at time 142 with 379.0 shares
# Buying Stock4 at time 143 with -367.0 shares
# Buying Stock4 at time 144 with 373.0 shares
# Buying Stock4 at time 145 with -335.0 shares
# Buying Stock4 at time 146 with -359.0 shares
# Buying Stock4 at time 147 with -440.0 shares
# Buying Stock4 at time 148 with -470.0 shares
# Buying Stock4 at time 149 with 529.0 shares
# Buying Stock4 at time 150 with 522.0 shares
# Buying Stock4 at time 151 with 526.0 shares
# Buying Stock4 at time 152 with 518.0 shares
# Buying Stock4 at time 153 with -489.0 shares
# Buying Stock4 at time 154 with -583.0 shares
# Buying Stock4 at time 155 with -598.0 shares
# Buying Stock4 at time 156 with -598.0 shares
# Buying Stock4 at time 157 with -612.0 shares
# Buying Stock4 at time 158 with 620.0 shares
# Buying Stock4 at time 159 with -604.0 shares
# Buying Stock4 at time 160 with -620.0 shares
# Buying Stock4 at time 161 with 617.0 shares
# Buying Stock4 at time 162 with -594.0 shares
# Buying Stock4 at time 163 with -618.0 shares
# Buying Stock4 at time 164 with -635.0 shares
# Buying Stock4 at time 165 with -643.0 shares
# Buying Stock4 at time 166 with -663.0 shares
# Buying Stock4 at time 167 with 723.0 shares
# Buying Stock4 at time 168 with -726.0 shares
# Buying Stock4 at time 169 with -722.0 shares
# Buying Stock4 at time 170 with -811.0 shares
# Buying Stock4 at time 171 with -881.0 shares
# Buying Stock4 at time 172 with 968.0 shares
# Buying Stock4 at time 173 with -945.0 shares
# Buying Stock4 at time 174 with 959.0 shares
# Buying Stock4 at time 175 with -951.0 shares
# Buying Stock4 at time 176 with -1005.0 shares
# Buying Stock4 at time 177 with 1044.0 shares
# Buying Stock4 at time 178 with -1009.0 shares
# Buying Stock4 at time 179 with 1065.0 shares
# Buying Stock4 at time 180 with -1008.0 shares
# Buying Stock4 at time 181 with -1081.0 shares
# Buying Stock4 at time 182 with -1088.0 shares
# Buying Stock4 at time 183 with 1102.0 shares
# Buying Stock4 at time 184 with 1103.0 shares
# Buying Stock4 at time 185 with 931.0 shares
# Buying Stock4 at time 186 with -927.0 shares
# Buying Stock4 at time 187 with -926.0 shares
# Buying Stock4 at time 188 with 1033.0 shares
# Buying Stock4 at time 189 with -1025.0 shares
# Buying Stock4 at time 190 with 1026.0 shares
# Buying Stock4 at time 191 with -958.0 shares
# Buying Stock4 at time 192 with 1038.0 shares
# Buying Stock4 at time 193 with 1024.0 shares
# Buying Stock4 at time 194 with -1015.0 shares
# Buying Stock4 at time 195 with -1129.0 shares
# Buying Stock4 at time 196 with 1266.0 shares
# Buying Stock4 at time 197 with -1261.0 shares
# Buying Stock4 at time 198 with -1558.0 shares
# Buying Stock4 at time 199 with -1574.0 shares
# Buying Stock4 at time 200 with 1639.0 shares
# Buying Stock4 at time 201 with -1571.0 shares
# Buying Stock4 at time 202 with -1652.0 shares
# Buying Stock4 at time 203 with 1795.0 shares
# Buying Stock4 at time 204 with -1739.0 shares
# Buying Stock4 at time 205 with 1850.0 shares
# Buying Stock4 at time 206 with -1710.0 shares
# Buying Stock4 at time 207 with -1742.0 shares
# Buying Stock4 at time 208 with -1764.0 shares
# Buying Stock4 at time 209 with 1798.0 shares
# Buying Stock4 at time 210 with -1763.0 shares
# Buying Stock4 at time 211 with 2113.0 shares
# Buying Stock4 at time 212 with 2006.0 shares
# Buying Stock4 at time 213 with -1881.0 shares
# Buying Stock4 at time 214 with 1980.0 shares
# Buying Stock4 at time 215 with 1927.0 shares
# Buying Stock4 at time 216 with 1796.0 shares
# Buying Stock4 at time 217 with 1734.0 shares
# Buying Stock4 at time 218 with 1691.0 shares
# Buying Stock4 at time 219 with -1633.0 shares
# Buying Stock4 at time 220 with -1666.0 shares
# Buying Stock4 at time 221 with -2073.0 shares
# Buying Stock4 at time 222 with 2137.0 shares
# Buying Stock4 at time 223 with 2111.0 shares
# Buying Stock4 at time 224 with -2069.0 shares
# Buying Stock4 at time 225 with -2097.0 shares
# Buying Stock4 at time 226 with 2128.0 shares
# Buying Stock4 at time 227 with 2097.0 shares
# Buying Stock4 at time 228 with -2012.0 shares
# Buying Stock4 at time 229 with -2180.0 shares
# Buying Stock4 at time 230 with 2229.0 shares
# Buying Stock4 at time 231 with -2226.0 shares
# Buying Stock4 at time 232 with 2272.0 shares
# Buying Stock4 at time 233 with -2246.0 shares
# Buying Stock4 at time 234 with -2475.0 shares
# Buying Stock4 at time 235 with 2823.0 shares
# Buying Stock4 at time 236 with -2818.0 shares
# Buying Stock4 at time 237 with -2940.0 shares
# Buying Stock4 at time 238 with 2980.0 shares
# Buying Stock4 at time 239 with 2790.0 shares
# Buying Stock4 at time 240 with -2687.0 shares
# Buying Stock4 at time 241 with -2834.0 shares
# Buying Stock4 at time 242 with -3003.0 shares
# Buying Stock4 at time 243 with 3081.0 shares
# Buying Stock4 at time 244 with -2767.0 shares
# Buying Stock4 at time 245 with -2757.0 shares
# Buying Stock4 at time 246 with -2868.0 shares
# Buying Stock4 at time 247 with -3037.0 shares
# Buying Stock4 at time 248 with -3316.0 shares
# Buying Stock4 at time 249 with -3232.0 shares
# Buying Stock4 at time 250 with 3367.0 shares
# Buying Stock4 at time 251 with -3277.0 shares
# Buying Stock4 at time 252 with 3979.0 shares
# Buying Stock4 at time 253 with 3933.0 shares
# Buying Stock4 at time 254 with 3986.0 shares
# Buying Stock4 at time 255 with -3863.0 shares
# Buying Stock4 at time 256 with -3661.0 shares
# Buying Stock4 at time 257 with 3785.0 shares
# Buying Stock4 at time 258 with -3596.0 shares
# Buying Stock4 at time 259 with -3762.0 shares
# Buying Stock4 at time 260 with 3852.0 shares
# Buying Stock4 at time 261 with -3797.0 shares
# Buying Stock4 at time 262 with -3963.0 shares
# Buying Stock4 at time 263 with -4488.0 shares
# Buying Stock4 at time 264 with -4756.0 shares
# Buying Stock4 at time 265 with 4943.0 shares
# Buying Stock4 at time 266 with 4359.0 shares
# Buying Stock4 at time 267 with 4381.0 shares
# Buying Stock4 at time 268 with -4239.0 shares
# Buying Stock4 at time 269 with -4346.0 shares
# Buying Stock4 at time 270 with -4453.0 shares
# Buying Stock4 at time 271 with -4594.0 shares
# Buying Stock4 at time 272 with 4983.0 shares
# Buying Stock4 at time 273 with -4880.0 shares
# Buying Stock4 at time 274 with -5137.0 shares
# Buying Stock4 at time 275 with -5094.0 shares
# Buying Stock4 at time 276 with 5287.0 shares
# Buying Stock4 at time 277 with 5431.0 shares
# Buying Stock4 at time 278 with -5107.0 shares
# Buying Stock4 at time 279 with -5267.0 shares
# Buying Stock4 at time 280 with -5353.0 shares
# Buying Stock4 at time 281 with 5078.0 shares
# Buying Stock4 at time 282 with -4657.0 shares
# Buying Stock4 at time 283 with 4788.0 shares
# Buying Stock4 at time 284 with 4796.0 shares
# Buying Stock4 at time 285 with 4320.0 shares
# Buying Stock4 at time 286 with -4469.0 shares
# Buying Stock4 at time 287 with 4973.0 shares
# Buying Stock4 at time 288 with 4722.0 shares
# Buying Stock4 at time 289 with 4508.0 shares
# Buying Stock4 at time 290 with 4545.0 shares
# Buying Stock4 at time 291 with -4441.0 shares
# Buying Stock4 at time 292 with 4567.0 shares
# Buying Stock4 at time 293 with 4532.0 shares
# Buying Stock4 at time 294 with 4449.0 shares
# Buying Stock4 at time 295 with -4308.0 shares
# Buying Stock4 at time 296 with -4446.0 shares
# Buying Stock4 at time 297 with -4438.0 shares
# Buying Stock4 at time 298 with 4559.0 shares
# Buying Stock4 at time 299 with 3646.0 shares
# Buying Stock4 at time 300 with 3540.0 shares
# Buying Stock4 at time 301 with 3368.0 shares
# Buying Stock4 at time 302 with -2962.0 shares
# Buying Stock4 at time 303 with 3616.0 shares
# Buying Stock4 at time 304 with -3399.0 shares
# Buying Stock4 at time 305 with 3557.0 shares
# Buying Stock4 at time 306 with 3467.0 shares
# Buying Stock4 at time 307 with 3334.0 shares
# Buying Stock4 at time 308 with 3311.0 shares
# Buying Stock4 at time 309 with 3226.0 shares
# Buying Stock4 at time 310 with 3125.0 shares
# Buying Stock4 at time 311 with -2911.0 shares
# Buying Stock4 at time 312 with -2936.0 shares
# Buying Stock4 at time 313 with -3407.0 shares
# Buying Stock4 at time 314 with 3806.0 shares
# Buying Stock4 at time 315 with 3723.0 shares
# Buying Stock4 at time 316 with 3470.0 shares
# Buying Stock4 at time 317 with -3395.0 shares
# Buying Stock4 at time 318 with -4030.0 shares
# Buying Stock4 at time 319 with 4160.0 shares
# Buying Stock4 at time 320 with -4158.0 shares
# Buying Stock4 at time 321 with -4274.0 shares
# Buying Stock4 at time 322 with 4656.0 shares
# Buying Stock4 at time 323 with -4332.0 shares
# Buying Stock4 at time 324 with 4509.0 shares
# Buying Stock4 at time 325 with 4257.0 shares
# Buying Stock4 at time 326 with -4250.0 shares
# Buying Stock4 at time 327 with -4432.0 shares
# Buying Stock4 at time 328 with 4553.0 shares
# Buying Stock4 at time 329 with -4243.0 shares
# Buying Stock4 at time 330 with 4221.0 shares
# Buying Stock4 at time 331 with 4073.0 shares
# Buying Stock4 at time 332 with -3665.0 shares
# Buying Stock4 at time 333 with 4324.0 shares
# Buying Stock4 at time 334 with -4326.0 shares
# Buying Stock4 at time 335 with -4341.0 shares
# Buying Stock4 at time 336 with 4989.0 shares
# Buying Stock4 at time 337 with 4906.0 shares
# Buying Stock4 at time 338 with -4464.0 shares
# Buying Stock4 at time 339 with -4478.0 shares
# Buying Stock4 at time 340 with 4495.0 shares
# Buying Stock4 at time 341 with 4497.0 shares
# Buying Stock4 at time 342 with -4338.0 shares
# Buying Stock4 at time 343 with 4335.0 shares
# Buying Stock4 at time 344 with -4165.0 shares
# Buying Stock4 at time 345 with 4604.0 shares
# Buying Stock4 at time 346 with 4767.0 shares
# Buying Stock4 at time 347 with 4655.0 shares
# Buying Stock4 at time 348 with 4592.0 shares
# Buying Stock4 at time 349 with -4483.0 shares
# Buying Stock4 at time 350 with -4531.0 shares
# Buying Stock4 at time 351 with -4614.0 shares
# Buying Stock4 at time 352 with 5112.0 shares
# Buying Stock4 at time 353 with 5000.0 shares
# Buying Stock4 at time 354 with -4761.0 shares
# Buying Stock4 at time 355 with -5065.0 shares
# Buying Stock4 at time 356 with 5320.0 shares
# Buying Stock4 at time 357 with 4702.0 shares
# Buying Stock4 at time 358 with 4218.0 shares
# Buying Stock4 at time 359 with -3822.0 shares
# Buying Stock4 at time 360 with -4018.0 shares
# Buying Stock4 at time 361 with -4169.0 shares
# Buying Stock4 at time 362 with 4447.0 shares
# Buying Stock4 at time 363 with 4313.0 shares
# Buying Stock4 at time 364 with -3669.0 shares
# Buying Stock4 at time 365 with 3557.0 shares
# Buying Stock4 at time 366 with -3528.0 shares
# Buying Stock4 at time 367 with -3609.0 shares
# Buying Stock4 at time 368 with 3682.0 shares
# Buying Stock4 at time 369 with 3315.0 shares
# Buying Stock4 at time 370 with -3050.0 shares
# Buying Stock4 at time 371 with -3334.0 shares
# Buying Stock4 at time 372 with -3400.0 shares
# Buying Stock4 at time 373 with 4221.0 shares
# Buying Stock4 at time 374 with -4169.0 shares
# Buying Stock4 at time 375 with -4831.0 shares
# Buying Stock4 at time 376 with -5417.0 shares
# Buying Stock4 at time 377 with 7108.0 shares
# Buying Stock4 at time 378 with -6603.0 shares
# Buying Stock4 at time 379 with -6656.0 shares
# Buying Stock4 at time 380 with 7928.0 shares
# Buying Stock4 at time 381 with -7738.0 shares
# Buying Stock4 at time 382 with -8259.0 shares
# Buying Stock4 at time 383 with 8240.0 shares
# Buying Stock4 at time 384 with 8134.0 shares
# Buying Stock4 at time 385 with -7843.0 shares
# Buying Stock4 at time 386 with 8162.0 shares
# Buying Stock4 at time 387 with 7931.0 shares
# Buying Stock4 at time 388 with -6520.0 shares
# Buying Stock4 at time 389 with 7064.0 shares
# Buying Stock4 at time 390 with -6911.0 shares
# Buying Stock4 at time 391 with 7044.0 shares
# Buying Stock4 at time 392 with -7203.0 shares
# Buying Stock4 at time 393 with -7372.0 shares
# Buying Stock4 at time 394 with -7691.0 shares
# Buying Stock4 at time 395 with 7438.0 shares
# Buying Stock4 at time 396 with 6726.0 shares
# Buying Stock4 at time 397 with 6476.0 shares
# Buying Stock4 at time 398 with -6590.0 shares
# Buying Stock4 at time 399 with 6488.0 shares
# Buying Stock4 at time 400 with 6376.0 shares
# Buying Stock4 at time 401 with 5496.0 shares
# Buying Stock4 at time 402 with -5030.0 shares
# Buying Stock4 at time 403 with -5240.0 shares
# Buying Stock4 at time 404 with 6421.0 shares
# Buying Stock4 at time 405 with -5891.0 shares
# Buying Stock4 at time 406 with 6000.0 shares
# Buying Stock4 at time 407 with -5639.0 shares
# Buying Stock4 at time 408 with 5992.0 shares
# Buying Stock4 at time 409 with 5786.0 shares
# Buying Stock4 at time 410 with 5536.0 shares
# Buying Stock4 at time 411 with -5293.0 shares
# Buying Stock4 at time 412 with 5947.0 shares
# Buying Stock4 at time 413 with -5991.0 shares
# Buying Stock4 at time 414 with 6085.0 shares
# Buying Stock4 at time 415 with -5971.0 shares
# Buying Stock4 at time 416 with -6438.0 shares
# Buying Stock4 at time 417 with -6201.0 shares
# Buying Stock4 at time 418 with 7687.0 shares
# Buying Stock4 at time 419 with 7567.0 shares
# Buying Stock4 at time 420 with -6699.0 shares
# Buying Stock4 at time 421 with -6803.0 shares
# Buying Stock4 at time 422 with -7055.0 shares
# Buying Stock4 at time 423 with 6955.0 shares
# Buying Stock4 at time 424 with 6482.0 shares
# Buying Stock4 at time 425 with -5969.0 shares
# Buying Stock4 at time 426 with 5910.0 shares
# Buying Stock4 at time 427 with -5606.0 shares
# Buying Stock4 at time 428 with -5651.0 shares
# Buying Stock4 at time 429 with 6197.0 shares
# Buying Stock4 at time 430 with 6016.0 shares
# Buying Stock4 at time 431 with -5592.0 shares
# Buying Stock4 at time 432 with 5675.0 shares
# Buying Stock4 at time 433 with -5580.0 shares
# Buying Stock4 at time 434 with 5731.0 shares
# Buying Stock4 at time 435 with -5630.0 shares
# Buying Stock4 at time 436 with 5598.0 shares
# Buying Stock4 at time 437 with -5458.0 shares
# Buying Stock4 at time 438 with -5936.0 shares
# Buying Stock4 at time 439 with 5913.0 shares
# Buying Stock4 at time 440 with -5504.0 shares
# Buying Stock4 at time 441 with 5871.0 shares
# Buying Stock4 at time 442 with 5073.0 shares
# Buying Stock4 at time 443 with -4733.0 shares
# Buying Stock4 at time 444 with 4961.0 shares
# Buying Stock4 at time 445 with -4807.0 shares
# Buying Stock4 at time 446 with -4823.0 shares
# Buying Stock4 at time 447 with 4906.0 shares
# Buying Stock4 at time 448 with 4764.0 shares
# Buying Stock4 at time 449 with 4739.0 shares
# Buying Stock4 at time 450 with 4639.0 shares
# Buying Stock4 at time 451 with 4647.0 shares
# Buying Stock4 at time 452 with 3977.0 shares
# Buying Stock4 at time 453 with -3718.0 shares
# Buying Stock4 at time 454 with -3685.0 shares
# Buying Stock4 at time 455 with 3979.0 shares
# Buying Stock4 at time 456 with -3801.0 shares
# Buying Stock4 at time 457 with 3919.0 shares
# Buying Stock4 at time 458 with -3653.0 shares
# Buying Stock4 at time 459 with 3706.0 shares
# Buying Stock4 at time 460 with 3417.0 shares
# Buying Stock4 at time 461 with 3410.0 shares
# Buying Stock4 at time 462 with 3205.0 shares
# Buying Stock4 at time 463 with -3048.0 shares
# Buying Stock4 at time 464 with -3138.0 shares
# Buying Stock4 at time 465 with 3145.0 shares
# Buying Stock4 at time 466 with -3059.0 shares
# Buying Stock4 at time 467 with -3201.0 shares
# Buying Stock4 at time 468 with 3298.0 shares
# Buying Stock4 at time 469 with 3036.0 shares
# Buying Stock4 at time 470 with 2802.0 shares
# Buying Stock4 at time 471 with 2326.0 shares
# Buying Stock4 at time 472 with -2054.0 shares
# Buying Stock4 at time 473 with -2122.0 shares
# Buying Stock4 at time 474 with 2208.0 shares
# Buying Stock4 at time 475 with 2119.0 shares
# Buying Stock4 at time 476 with 1930.0 shares
# Buying Stock4 at time 477 with 1855.0 shares
# Buying Stock4 at time 478 with -1848.0 shares
# Buying Stock4 at time 479 with 1916.0 shares
# Buying Stock4 at time 480 with 1813.0 shares
# Buying Stock4 at time 481 with -1725.0 shares
# Buying Stock4 at time 482 with 1763.0 shares
# Buying Stock4 at time 483 with 1655.0 shares
# Buying Stock4 at time 484 with 1660.0 shares
# Buying Stock4 at time 485 with 1433.0 shares
# Buying Stock4 at time 486 with -1341.0 shares
# Buying Stock4 at time 487 with -1332.0 shares
# Buying Stock4 at time 488 with 1388.0 shares
# Buying Stock4 at time 489 with 1383.0 shares
# Buying Stock4 at time 490 with -1336.0 shares
# Buying Stock4 at time 491 with -1512.0 shares
# Buying Stock4 at time 492 with -1590.0 shares
# Buying Stock4 at time 493 with -1751.0 shares
# Buying Stock4 at time 494 with -2054.0 shares
# Buying Stock4 at time 495 with -2063.0 shares
# Buying Stock4 at time 496 with 2099.0 shares
# Buying Stock4 at time 497 with -1966.0 shares
# Buying Stock4 at time 498 with -2114.0 shares
# Buying Stock4 at time 499 with -2198.0 shares
# Buying Stock4 at time 500 with -2338.0 shares
# Buying Stock4 at time 501 with 2387.0 shares
# Buying Stock4 at time 502 with 2129.0 shares
# Buying Stock4 at time 503 with -1839.0 shares
# Buying Stock4 at time 504 with -1888.0 shares
# Buying Stock4 at time 505 with 2039.0 shares
# Buying Stock4 at time 506 with 1916.0 shares
# Buying Stock4 at time 507 with -1843.0 shares
# Buying Stock4 at time 508 with 1924.0 shares
# Buying Stock4 at time 509 with 1832.0 shares
# Buying Stock4 at time 510 with -1800.0 shares
# Buying Stock4 at time 511 with -1891.0 shares
# Buying Stock4 at time 512 with 1973.0 shares
# Buying Stock4 at time 513 with -1939.0 shares
# Buying Stock4 at time 514 with -2034.0 shares
# Buying Stock4 at time 515 with -2219.0 shares
# Buying Stock4 at time 516 with -2250.0 shares
# Buying Stock4 at time 517 with -2353.0 shares
# Buying Stock4 at time 518 with -2516.0 shares
# Buying Stock4 at time 519 with 2559.0 shares
# Buying Stock4 at time 520 with 2507.0 shares
# Buying Stock4 at time 521 with 2454.0 shares
# Buying Stock4 at time 522 with -2134.0 shares
# Buying Stock4 at time 523 with -2303.0 shares
# Buying Stock4 at time 524 with -2435.0 shares
# Buying Stock4 at time 525 with 2610.0 shares
# Buying Stock4 at time 526 with -2293.0 shares
# Buying Stock4 at time 527 with -2556.0 shares
# Buying Stock4 at time 528 with -2743.0 shares
# Buying Stock4 at time 529 with 3358.0 shares
# Buying Stock4 at time 530 with -3059.0 shares
# Buying Stock4 at time 531 with 3063.0 shares
# Buying Stock4 at time 532 with -2749.0 shares
# Buying Stock4 at time 533 with -2942.0 shares
# Buying Stock4 at time 534 with -2995.0 shares
# Buying Stock4 at time 535 with -3157.0 shares
# Buying Stock4 at time 536 with 3134.0 shares
# Buying Stock4 at time 537 with 2842.0 shares
# Buying Stock4 at time 538 with 2714.0 shares
# Buying Stock4 at time 539 with 2645.0 shares
# Buying Stock4 at time 540 with 2542.0 shares
# Buying Stock4 at time 541 with 2167.0 shares
# Buying Stock4 at time 542 with -2102.0 shares
# Buying Stock4 at time 543 with 2305.0 shares
# Buying Stock4 at time 544 with 2212.0 shares
# Buying Stock4 at time 545 with 2197.0 shares
# Buying Stock4 at time 546 with 2184.0 shares
# Buying Stock4 at time 547 with 1987.0 shares
# Buying Stock4 at time 548 with -1850.0 shares
# Buying Stock4 at time 549 with -1925.0 shares
# Buying Stock4 at time 550 with -2119.0 shares
# Buying Stock4 at time 551 with 2300.0 shares
# Buying Stock4 at time 552 with -2301.0 shares
# Buying Stock4 at time 553 with 2386.0 shares
# Buying Stock4 at time 554 with 2163.0 shares
# Buying Stock4 at time 555 with 2130.0 shares
# Buying Stock4 at time 556 with 2011.0 shares
# Buying Stock4 at time 557 with 1664.0 shares
# Buying Stock4 at time 558 with -1435.0 shares
# Buying Stock4 at time 559 with 1687.0 shares
# Buying Stock4 at time 560 with 1645.0 shares
# Buying Stock4 at time 561 with 1595.0 shares
# Buying Stock4 at time 562 with 1481.0 shares
# Buying Stock4 at time 563 with 1260.0 shares
# Buying Stock4 at time 564 with 1025.0 shares
# Buying Stock4 at time 565 with 1001.0 shares
# Buying Stock4 at time 566 with -979.0 shares
# Buying Stock4 at time 567 with 1011.0 shares
# Buying Stock4 at time 568 with -904.0 shares
# Buying Stock4 at time 569 with -933.0 shares
# Buying Stock4 at time 570 with -1008.0 shares
# Buying Stock4 at time 571 with -1123.0 shares
# Buying Stock4 at time 572 with 1130.0 shares
# Buying Stock4 at time 573 with 1122.0 shares
# Buying Stock4 at time 574 with 1087.0 shares
# Buying Stock4 at time 575 with -985.0 shares
# Buying Stock4 at time 576 with 1098.0 shares
# Buying Stock4 at time 577 with 1008.0 shares
# Buying Stock4 at time 578 with 859.0 shares
# Buying Stock4 at time 579 with -642.0 shares
# Buying Stock4 at time 580 with -683.0 shares
# Buying Stock4 at time 581 with 679.0 shares
# Buying Stock4 at time 582 with 668.0 shares
# Buying Stock4 at time 583 with 653.0 shares
# Buying Stock4 at time 584 with -658.0 shares
# Buying Stock4 at time 585 with 677.0 shares
# Buying Stock4 at time 586 with 628.0 shares
# Buying Stock4 at time 587 with 627.0 shares
# Buying Stock4 at time 588 with -647.0 shares
# Buying Stock4 at time 589 with -651.0 shares
# Buying Stock4 at time 590 with 669.0 shares
# Buying Stock4 at time 591 with -661.0 shares
# Buying Stock4 at time 592 with -747.0 shares
# Buying Stock4 at time 593 with 784.0 shares
# Buying Stock4 at time 594 with 767.0 shares
# Buying Stock4 at time 595 with 768.0 shares
# Buying Stock4 at time 596 with 723.0 shares
# Buying Stock4 at time 597 with -675.0 shares
# Buying Stock4 at time 598 with -695.0 shares
# Buying Stock4 at time 599 with -759.0 shares
# Buying Stock4 at time 600 with 725.0 shares
# Buying Stock4 at time 601 with 707.0 shares
# Buying Stock4 at time 602 with 689.0 shares
# Buying Stock4 at time 603 with -660.0 shares
# Buying Stock4 at time 604 with 673.0 shares
# Buying Stock4 at time 605 with 602.0 shares
# Buying Stock4 at time 606 with -509.0 shares
# Buying Stock4 at time 607 with -483.0 shares
# Buying Stock4 at time 608 with 506.0 shares
# Buying Stock4 at time 609 with 487.0 shares
# Buying Stock4 at time 610 with 490.0 shares
# Buying Stock4 at time 611 with 454.0 shares
# Buying Stock4 at time 612 with 443.0 shares
# Buying Stock4 at time 613 with -433.0 shares
# Buying Stock4 at time 614 with 442.0 shares
# Buying Stock4 at time 615 with 430.0 shares
# Buying Stock4 at time 616 with 417.0 shares
# Buying Stock4 at time 617 with 412.0 shares
# Buying Stock4 at time 618 with 402.0 shares
# Buying Stock4 at time 619 with 407.0 shares
# Buying Stock4 at time 620 with -396.0 shares
# Buying Stock4 at time 621 with -434.0 shares
# Buying Stock4 at time 622 with 423.0 shares
# Buying Stock4 at time 623 with 396.0 shares
# Buying Stock4 at time 624 with 368.0 shares
# Buying Stock4 at time 625 with -339.0 shares
# Buying Stock4 at time 626 with 342.0 shares
# Buying Stock4 at time 627 with -327.0 shares
# Buying Stock4 at time 628 with -343.0 shares
# Buying Stock4 at time 629 with 435.0 shares
# Buying Stock4 at time 630 with 426.0 shares
# Buying Stock4 at time 631 with -401.0 shares
# Buying Stock4 at time 632 with -426.0 shares
# Buying Stock4 at time 633 with 423.0 shares
# Buying Stock4 at time 634 with 333.0 shares
# Buying Stock4 at time 635 with -329.0 shares
# Buying Stock4 at time 636 with 498.0 shares
# Buying Stock4 at time 637 with -483.0 shares
# Buying Stock4 at time 638 with -516.0 shares
# Buying Stock4 at time 639 with -546.0 shares
# Buying Stock4 at time 640 with -546.0 shares
# Buying Stock4 at time 641 with -587.0 shares
# Buying Stock4 at time 642 with -577.0 shares
# Buying Stock4 at time 643 with 617.0 shares
# Buying Stock4 at time 644 with -607.0 shares
# Buying Stock4 at time 645 with -615.0 shares
# Buying Stock4 at time 646 with 624.0 shares
# Buying Stock4 at time 647 with -544.0 shares
# Buying Stock4 at time 648 with 585.0 shares
# Buying Stock4 at time 649 with 545.0 shares
# Buying Stock4 at time 650 with 505.0 shares
# Buying Stock4 at time 651 with -430.0 shares
# Buying Stock4 at time 652 with 433.0 shares
# Buying Stock4 at time 653 with -428.0 shares
# Buying Stock4 at time 654 with 442.0 shares
# Buying Stock4 at time 655 with 434.0 shares
# Buying Stock4 at time 656 with 403.0 shares
# Buying Stock4 at time 657 with 379.0 shares
# Buying Stock4 at time 658 with -344.0 shares
# Buying Stock4 at time 659 with -385.0 shares
# Buying Stock4 at time 660 with 450.0 shares
# Buying Stock4 at time 661 with -425.0 shares
# Buying Stock4 at time 662 with -438.0 shares
# Buying Stock4 at time 663 with -479.0 shares
# Buying Stock4 at time 664 with 482.0 shares
# Buying Stock4 at time 665 with -487.0 shares
# Buying Stock4 at time 666 with -517.0 shares
# Buying Stock4 at time 667 with -582.0 shares
# Buying Stock4 at time 668 with -635.0 shares
# Buying Stock4 at time 669 with 588.0 shares
# Buying Stock4 at time 670 with 576.0 shares
# Buying Stock4 at time 671 with -573.0 shares
# Buying Stock4 at time 672 with 589.0 shares
# Buying Stock4 at time 673 with -573.0 shares
# Buying Stock4 at time 674 with 609.0 shares
# Buying Stock4 at time 675 with 390.0 shares
# Buying Stock4 at time 676 with 369.0 shares
# Buying Stock4 at time 677 with 366.0 shares
# Buying Stock4 at time 678 with 336.0 shares
# Buying Stock4 at time 679 with 323.0 shares
# Buying Stock4 at time 680 with 285.0 shares
# Buying Stock4 at time 681 with 282.0 shares
# Buying Stock4 at time 682 with -277.0 shares
# Buying Stock4 at time 683 with -292.0 shares
# Buying Stock4 at time 684 with 351.0 shares
# Buying Stock4 at time 685 with 333.0 shares
# Buying Stock4 at time 686 with -310.0 shares
# Buying Stock4 at time 687 with -322.0 shares
# Buying Stock4 at time 688 with 324.0 shares
# Buying Stock4 at time 689 with -304.0 shares
# Buying Stock4 at time 690 with -307.0 shares
# Buying Stock4 at time 691 with -327.0 shares
# Buying Stock4 at time 692 with 327.0 shares
# Buying Stock4 at time 693 with -322.0 shares
# Buying Stock4 at time 694 with 374.0 shares
# Buying Stock4 at time 695 with -363.0 shares
# Buying Stock4 at time 696 with -356.0 shares
# Buying Stock4 at time 697 with 366.0 shares
# Buying Stock4 at time 698 with 346.0 shares
# Buying Stock4 at time 699 with -325.0 shares
# Buying Stock4 at time 700 with -337.0 shares
# Buying Stock4 at time 701 with -379.0 shares
# Buying Stock4 at time 702 with 394.0 shares
# Buying Stock4 at time 703 with -382.0 shares
# Buying Stock4 at time 704 with -385.0 shares
# Buying Stock4 at time 705 with -418.0 shares
# Buying Stock4 at time 706 with 486.0 shares
# Buying Stock4 at time 707 with -441.0 shares
# Buying Stock4 at time 708 with 512.0 shares
# Buying Stock4 at time 709 with -510.0 shares
# Buying Stock4 at time 710 with -561.0 shares
# Buying Stock4 at time 711 with -631.0 shares
# Buying Stock4 at time 712 with -632.0 shares
# Buying Stock4 at time 713 with -641.0 shares
# Buying Stock4 at time 714 with 741.0 shares
# Buying Stock4 at time 715 with 744.0 shares
# Buying Stock4 at time 716 with -733.0 shares
# Buying Stock4 at time 717 with -788.0 shares
# Buying Stock4 at time 718 with -855.0 shares
# Buying Stock4 at time 719 with 875.0 shares
# Buying Stock4 at time 720 with 817.0 shares
# Buying Stock4 at time 721 with -747.0 shares
# Buying Stock4 at time 722 with 852.0 shares
# Buying Stock4 at time 723 with -801.0 shares
# Buying Stock4 at time 724 with 838.0 shares
# Buying Stock4 at time 725 with 747.0 shares
# Buying Stock4 at time 726 with 733.0 shares
# Buying Stock4 at time 727 with 639.0 shares
# Buying Stock4 at time 728 with 614.0 shares
# Buying Stock4 at time 729 with -602.0 shares
# Buying Stock4 at time 730 with 610.0 shares
# Buying Stock4 at time 731 with -605.0 shares
# Buying Stock4 at time 732 with 707.0 shares
# Buying Stock4 at time 733 with 668.0 shares
# Buying Stock4 at time 734 with -583.0 shares
# Buying Stock4 at time 735 with -602.0 shares
# Buying Stock4 at time 736 with -641.0 shares
# Buying Stock4 at time 737 with 703.0 shares
# Buying Stock4 at time 738 with -687.0 shares
# Buying Stock4 at time 739 with 721.0 shares
# Buying Stock4 at time 740 with 700.0 shares
# Buying Stock4 at time 741 with 637.0 shares
# Buying Stock4 at time 742 with 605.0 shares
# Buying Stock4 at time 743 with -598.0 shares
# Buying Stock4 at time 744 with -619.0 shares
# Buying Stock4 at time 745 with 624.0 shares
# Buying Stock4 at time 746 with -619.0 shares
# Buying Stock4 at time 747 with -642.0 shares
# Buying Stock4 at time 748 with -731.0 shares
# Buying Stock4 at time 749 with -741.0 shares
# Buying Stock4 at time 750 with -745.0 shares
# Buying Stock4 at time 751 with -827.0 shares
# Buying Stock4 at time 752 with -850.0 shares
# Buying Stock4 at time 753 with -946.0 shares
# Buying Stock4 at time 754 with 1000.0 shares
# Buying Stock4 at time 755 with -991.0 shares
# Buying Stock4 at time 756 with -1095.0 shares
# Buying Stock4 at time 757 with 1087.0 shares
# Buying Stock4 at time 758 with -993.0 shares
# Buying Stock4 at time 759 with 967.0 shares
# Buying Stock4 at time 760 with 909.0 shares
# Buying Stock4 at time 761 with -893.0 shares
# Buying Stock4 at time 762 with -936.0 shares
# Buying Stock4 at time 763 with 1006.0 shares
# Buying Stock4 at time 764 with -975.0 shares
# Buying Stock4 at time 765 with 1009.0 shares
# Buying Stock4 at time 766 with -939.0 shares
# Buying Stock4 at time 767 with 939.0 shares
# Buying Stock4 at time 768 with 914.0 shares
# Buying Stock4 at time 769 with -822.0 shares
# Buying Stock4 at time 770 with 885.0 shares
# Buying Stock4 at time 771 with -853.0 shares
# Buying Stock4 at time 772 with 883.0 shares
# Buying Stock4 at time 773 with 809.0 shares
# Buying Stock4 at time 774 with 721.0 shares
# Buying Stock4 at time 775 with -700.0 shares
# Buying Stock4 at time 776 with -726.0 shares
# Buying Stock4 at time 777 with -738.0 shares
# Buying Stock4 at time 778 with 755.0 shares
# Buying Stock4 at time 779 with -735.0 shares
# Buying Stock4 at time 780 with 747.0 shares
# Buying Stock4 at time 781 with 721.0 shares
# Buying Stock4 at time 782 with 709.0 shares
# Buying Stock4 at time 783 with -643.0 shares
# Buying Stock4 at time 784 with 646.0 shares
# Buying Stock4 at time 785 with -633.0 shares
# Buying Stock4 at time 786 with 669.0 shares
# Buying Stock4 at time 787 with 580.0 shares
# Buying Stock4 at time 788 with 564.0 shares
# Buying Stock4 at time 789 with 518.0 shares
# Buying Stock4 at time 790 with 477.0 shares
# Buying Stock4 at time 791 with 364.0 shares
# Buying Stock4 at time 792 with -362.0 shares
# Buying Stock4 at time 793 with 402.0 shares
# Buying Stock4 at time 794 with 356.0 shares
# Buying Stock4 at time 795 with 315.0 shares
# Buying Stock4 at time 796 with 302.0 shares
# Buying Stock4 at time 797 with -292.0 shares
# Buying Stock4 at time 798 with 296.0 shares
# Buying Stock4 at time 799 with -273.0 shares
#       Stock1   Stock2   Stock3   Stock4  Stock1_Next  Stock2_Next  \
# 0    1479.36  1088.26  1545.61  1304.27      1479.33      1087.03
# 1    1479.33  1087.03  1544.94  1305.82      1479.72      1087.16
# 2    1479.72  1087.16  1543.55  1287.43      1477.47      1077.92
# 3    1477.47  1077.92  1545.35  1193.67      1474.91      1076.45
# 4    1474.91  1076.45  1545.01  1296.92      1472.41      1074.89
# ..       ...      ...      ...      ...          ...          ...
# 795   785.90   938.11  1548.77  1904.48       786.96       939.40
# 796   786.96   939.40  1549.56  1981.77       787.78       944.30
# 797   787.78   944.30  1548.68  2060.57       787.57       944.60
# 798   787.57   944.60  1551.01  2023.45       788.28       972.23
# 799   788.28   972.23  1550.34  2205.54       788.28       972.23
#
#      Stock3_Next  Stock4_Next  Stock1_Positions  Stock2_Positions  \
# 0        1544.94      1305.82                 0                 0
# 1        1543.55      1287.43                 0                 0
# 2        1545.35      1193.67                 0                 0
# 3        1545.01      1296.92                 0                 0
# 4        1544.71      1270.44                 0                 0
# ..           ...          ...               ...               ...
# 795      1549.56      1981.77                 0                 0
# 796      1548.68      2060.57                 0                 0
# 797      1551.01      2023.45                 0                 0
# 798      1550.34      2205.54                 0                 0
# 799      1550.34      2205.54                 0                 0
#
#      Stock3_Positions  Stock4_Positions       Pnl  Stock1_Pnl  Stock2_Pnl  \
# 0                   0               0.0      0.00        -0.0        -0.0
# 1                   0               0.0      0.00         0.0         0.0
# 2                   0             466.0 -43692.16        -0.0        -0.0
# 3                   0             502.0  51831.50        -0.0        -0.0
# 4                   0            -462.0  12233.76        -0.0        -0.0
# ..                ...               ...       ...         ...         ...
# 795                 0             315.0  24346.35         0.0         0.0
# 796                 0             302.0  23797.60         0.0         0.0
# 797                 0            -291.0  10801.92        -0.0         0.0
# 798                 0             296.0  53898.64         0.0         0.0
# 799                 0            -272.0      0.00         0.0         0.0
#
#      Stock3_Pnl  Stock4_Pnl
# 0          -0.0        0.00
# 1          -0.0       -0.00
# 2           0.0   -43692.16
# 3          -0.0    51831.50
# 4          -0.0    12233.76
# ..          ...         ...
# 795         0.0    24346.35
# 796        -0.0    23797.60
# 797         0.0    10801.92
# 798        -0.0    53898.64
# 799         0.0       -0.00
#
# [800 rows x 17 columns]

# %%
results.pnl
# Out:
# 25181467.57

# %%
trader = RegressionTrader()
game = Game(trader, train)
results = game.run_game([], n_stocks=4)
results.history
# Out:
# Predicted Stock4 return: -0.05517124183419466
# Buying Stock4 at time 2 with -466.0 shares
# Predicted Stock4 return: 0.07904438331066396
# Buying Stock4 at time 3 with 503.0 shares
# Predicted Stock4 return: -0.011012328173870057
# Buying Stock4 at time 4 with -462.0 shares
# Predicted Stock4 return: -0.00933345016220548
# Buying Stock4 at time 5 with -472.0 shares
# Predicted Stock4 return: -0.024897640228187547
# Buying Stock4 at time 6 with -479.0 shares
# Predicted Stock4 return: -0.09686155052849368
# Buying Stock4 at time 7 with -489.0 shares
# Predicted Stock4 return: -0.042653015390589265
# Buying Stock4 at time 8 with -535.0 shares
# Predicted Stock4 return: 0.06653940008990453
# Buying Stock4 at time 9 with 557.0 shares
# Predicted Stock4 return: -0.03421465025668835
# Buying Stock4 at time 10 with -533.0 shares
# Predicted Stock4 return: -0.015266512920960314
# Buying Stock4 at time 11 with -546.0 shares
# Predicted Stock4 return: 0.07327916109936355
# Buying Stock4 at time 12 with 567.0 shares
# Predicted Stock4 return: 0.05256417075243625
# Buying Stock4 at time 13 with 537.0 shares
# Predicted Stock4 return: 0.029377414872962093
# Buying Stock4 at time 14 with 535.0 shares
# Predicted Stock4 return: 0.026842562121775226
# Buying Stock4 at time 15 with 525.0 shares
# Predicted Stock4 return: 0.020104794036426243
# Buying Stock4 at time 16 with 523.0 shares
# Predicted Stock4 return: 0.050794588500803435
# Buying Stock4 at time 17 with 516.0 shares
# Predicted Stock4 return: -0.33410717845671645
# Buying Stock4 at time 18 with -518.0 shares
# Predicted Stock4 return: 0.0205982351287362
# Buying Stock4 at time 19 with 737.0 shares
# Predicted Stock4 return: 0.03959448011228604
# Buying Stock4 at time 20 with 726.0 shares
# Predicted Stock4 return: 0.05012433138367433
# Buying Stock4 at time 21 with 711.0 shares
# Predicted Stock4 return: 0.020571484195932146
# Buying Stock4 at time 22 with 690.0 shares
# Predicted Stock4 return: -0.035082890481633516
# Buying Stock4 at time 23 with -653.0 shares
# Predicted Stock4 return: 0.06360460407203866
# Buying Stock4 at time 24 with 666.0 shares
# Predicted Stock4 return: -0.10250146790992484
# Buying Stock4 at time 25 with -603.0 shares
# Predicted Stock4 return: 0.03029832332777887
# Buying Stock4 at time 26 with 662.0 shares
# Predicted Stock4 return: -0.03427261087061469
# Buying Stock4 at time 27 with -656.0 shares
# Predicted Stock4 return: -0.0566710850234846
# Buying Stock4 at time 28 with -680.0 shares
# Predicted Stock4 return: 0.012578770005177422
# Buying Stock4 at time 29 with 724.0 shares
# Predicted Stock4 return: -0.07108397614365067
# Buying Stock4 at time 30 with -733.0 shares
# Predicted Stock4 return: 0.11453509423319908
# Buying Stock4 at time 31 with 797.0 shares
# Predicted Stock4 return: 0.060291344395241926
# Buying Stock4 at time 32 with 700.0 shares
# Predicted Stock4 return: -0.005156737643949605
# Buying Stock4 at time 33 with -661.0 shares
# Predicted Stock4 return: 0.024380628705510027
# Buying Stock4 at time 34 with 669.0 shares
# Predicted Stock4 return: 0.008343819392937307
# Buying Stock4 at time 35 with 656.0 shares
# Predicted Stock4 return: 0.011717890407829938
# Buying Stock4 at time 36 with 655.0 shares
# Predicted Stock4 return: -0.02919328571679764
# Buying Stock4 at time 37 with -644.0 shares
# Predicted Stock4 return: 0.0235360148643242
# Buying Stock4 at time 38 with 665.0 shares
# Predicted Stock4 return: 0.1893100022863798
# Buying Stock4 at time 39 with 661.0 shares
# Predicted Stock4 return: 0.031463830673147654
# Buying Stock4 at time 40 with 547.0 shares
# Predicted Stock4 return: -0.024888157322140444
# Buying Stock4 at time 41 with -532.0 shares
# Predicted Stock4 return: 0.02725754652825433
# Buying Stock4 at time 42 with 530.0 shares
# Predicted Stock4 return: 0.01715734396249999
# Buying Stock4 at time 43 with 510.0 shares
# Predicted Stock4 return: -0.004285175398524345
# Buying Stock4 at time 44 with -501.0 shares
# Predicted Stock4 return: -0.022785083695592633
# Buying Stock4 at time 45 with -498.0 shares
# Predicted Stock4 return: 0.09034617185717228
# Buying Stock4 at time 46 with 523.0 shares
# Predicted Stock4 return: 0.14399455396398061
# Buying Stock4 at time 47 with 475.0 shares
# Predicted Stock4 return: -0.026057408930542068
# Buying Stock4 at time 48 with -411.0 shares
# Predicted Stock4 return: 0.13494816683282188
# Buying Stock4 at time 49 with 399.0 shares
# Predicted Stock4 return: -0.017641862612884265
# Buying Stock4 at time 50 with -348.0 shares
# Predicted Stock4 return: 0.052677306352535265
# Buying Stock4 at time 51 with 363.0 shares
# Predicted Stock4 return: 0.006209746968786334
# Buying Stock4 at time 52 with 360.0 shares
# Predicted Stock4 return: 0.0760606599634209
# Buying Stock4 at time 53 with 371.0 shares
# Predicted Stock4 return: -0.02303978029353269
# Buying Stock4 at time 54 with -348.0 shares
# Predicted Stock4 return: 0.12950898073531628
# Buying Stock4 at time 55 with 358.0 shares
# Predicted Stock4 return: 0.0016130847451999684
# Buying Stock4 at time 56 with 318.0 shares
# Predicted Stock4 return: -0.009650581966756642
# Buying Stock4 at time 57 with -313.0 shares
# Predicted Stock4 return: 0.03207227431442669
# Buying Stock4 at time 58 with 316.0 shares
# Predicted Stock4 return: -0.0359228049483276
# Buying Stock4 at time 59 with -303.0 shares
# Predicted Stock4 return: -0.07016682461585097
# Buying Stock4 at time 60 with -314.0 shares
# Predicted Stock4 return: 0.026260377170895417
# Buying Stock4 at time 61 with 346.0 shares
# Predicted Stock4 return: 0.048387486761594996
# Buying Stock4 at time 62 with 334.0 shares
# Predicted Stock4 return: 0.10887283705579923
# Buying Stock4 at time 63 with 306.0 shares
# Predicted Stock4 return: -0.10588815884517644
# Buying Stock4 at time 64 with -282.0 shares
# Predicted Stock4 return: -0.027187034833966256
# Buying Stock4 at time 65 with -310.0 shares
# Predicted Stock4 return: -0.03471770104597758
# Buying Stock4 at time 66 with -323.0 shares
# Predicted Stock4 return: 0.06720826493868029
# Buying Stock4 at time 67 with 337.0 shares
# Predicted Stock4 return: -0.07393908520356882
# Buying Stock4 at time 68 with -308.0 shares
# Predicted Stock4 return: -0.12167232060843503
# Buying Stock4 at time 69 with -337.0 shares
# Predicted Stock4 return: -0.01974742329042694
# Buying Stock4 at time 70 with -365.0 shares
# Predicted Stock4 return: -0.013891545126957287
# Buying Stock4 at time 71 with -376.0 shares
# Predicted Stock4 return: -0.01808579617997212
# Buying Stock4 at time 72 with -381.0 shares
# Predicted Stock4 return: -0.005938668492606441
# Buying Stock4 at time 73 with -389.0 shares
# Predicted Stock4 return: -0.09857618708383295
# Buying Stock4 at time 74 with -395.0 shares
# Predicted Stock4 return: -0.03198370544137148
# Buying Stock4 at time 75 with -427.0 shares
# Predicted Stock4 return: 0.04234680324130473
# Buying Stock4 at time 76 with 447.0 shares
# Predicted Stock4 return: 0.05491739266720915
# Buying Stock4 at time 77 with 439.0 shares
# Predicted Stock4 return: -0.018950118210309917
# Buying Stock4 at time 78 with -412.0 shares
# Predicted Stock4 return: -0.08147997071730051
# Buying Stock4 at time 79 with -414.0 shares
# Predicted Stock4 return: 0.15874112289594253
# Buying Stock4 at time 80 with 461.0 shares
# Predicted Stock4 return: 0.002443411796496118
# Buying Stock4 at time 81 with 380.0 shares
# Predicted Stock4 return: 0.11771321540544849
# Buying Stock4 at time 82 with 376.0 shares
# Predicted Stock4 return: 0.043450620302091056
# Buying Stock4 at time 83 with 326.0 shares
# Predicted Stock4 return: 0.05178914850341874
# Buying Stock4 at time 84 with 314.0 shares
# Predicted Stock4 return: 0.04673869314511392
# Buying Stock4 at time 85 with 300.0 shares
# Predicted Stock4 return: 0.011215673397057785
# Buying Stock4 at time 86 with 288.0 shares
# Predicted Stock4 return: -0.018847105689249105
# Buying Stock4 at time 87 with -287.0 shares
# Predicted Stock4 return: -0.0021479493520515248
# Buying Stock4 at time 88 with -292.0 shares
# Predicted Stock4 return: -0.045171741427264225
# Buying Stock4 at time 89 with -289.0 shares
# Predicted Stock4 return: 0.0053717972395063394
# Buying Stock4 at time 90 with 301.0 shares
# Predicted Stock4 return: -0.08115439836835911
# Buying Stock4 at time 91 with -297.0 shares
# Predicted Stock4 return: 0.12633383334255413
# Buying Stock4 at time 92 with 326.0 shares
# Predicted Stock4 return: -0.021783473769615393
# Buying Stock4 at time 93 with -290.0 shares
# Predicted Stock4 return: 0.002027983168214227
# Buying Stock4 at time 94 with 293.0 shares
# Predicted Stock4 return: -0.020957786390961887
# Buying Stock4 at time 95 with -300.0 shares
# Predicted Stock4 return: -0.0017352166146929115
# Buying Stock4 at time 96 with -307.0 shares
# Predicted Stock4 return: 0.06767080756476698
# Buying Stock4 at time 97 with 315.0 shares
# Predicted Stock4 return: 0.034191300624473994
# Buying Stock4 at time 98 with 298.0 shares
# Predicted Stock4 return: 0.01246668977549905
# Buying Stock4 at time 99 with 285.0 shares
# Predicted Stock4 return: 0.023318813146158537
# Buying Stock4 at time 100 with 287.0 shares
# Predicted Stock4 return: -0.002977931995322633
# Buying Stock4 at time 101 with -281.0 shares
# Predicted Stock4 return: -0.029271635849982686
# Buying Stock4 at time 102 with -286.0 shares
# Predicted Stock4 return: -0.02761771520380747
# Buying Stock4 at time 103 with -292.0 shares
# Predicted Stock4 return: 0.08725122901506246
# Buying Stock4 at time 104 with 304.0 shares
# Predicted Stock4 return: 0.02372548123409172
# Buying Stock4 at time 105 with 283.0 shares
# Predicted Stock4 return: -0.04009544906169005
# Buying Stock4 at time 106 with -274.0 shares
# Predicted Stock4 return: -0.12484990870297025
# Buying Stock4 at time 107 with -284.0 shares
# Predicted Stock4 return: 0.07646526611528637
# Buying Stock4 at time 108 with 318.0 shares
# Predicted Stock4 return: -0.05060429664343971
# Buying Stock4 at time 109 with -289.0 shares
# Predicted Stock4 return: -0.056501977821771035
# Buying Stock4 at time 110 with -303.0 shares
# Predicted Stock4 return: 0.07902170598438057
# Buying Stock4 at time 111 with 324.0 shares
# Predicted Stock4 return: 0.05510946890027736
# Buying Stock4 at time 112 with 302.0 shares
# Predicted Stock4 return: 0.06550896955404023
# Buying Stock4 at time 113 with 288.0 shares
# Predicted Stock4 return: 0.019136576084869066
# Buying Stock4 at time 114 with 271.0 shares
# Predicted Stock4 return: -0.021746137723251506
# Buying Stock4 at time 115 with -274.0 shares
# Predicted Stock4 return: 0.02164256744603867
# Buying Stock4 at time 116 with 290.0 shares
# Predicted Stock4 return: 0.02288890173300877
# Buying Stock4 at time 117 with 284.0 shares
# Predicted Stock4 return: -0.06469710845285215
# Buying Stock4 at time 118 with -277.0 shares
# Predicted Stock4 return: 0.136876894357993
# Buying Stock4 at time 119 with 298.0 shares
# Predicted Stock4 return: -0.018799566850883787
# Buying Stock4 at time 120 with -252.0 shares
# Predicted Stock4 return: 0.011200353753889697
# Buying Stock4 at time 121 with 260.0 shares
# Predicted Stock4 return: -0.11089929086112257
# Buying Stock4 at time 122 with -259.0 shares
# Predicted Stock4 return: 0.1339444244854781
# Buying Stock4 at time 123 with 289.0 shares
# Predicted Stock4 return: -0.05754403765866178
# Buying Stock4 at time 124 with -257.0 shares
# Predicted Stock4 return: -0.11264572982987367
# Buying Stock4 at time 125 with -279.0 shares
# Predicted Stock4 return: 0.0036994775607063425
# Buying Stock4 at time 126 with 311.0 shares
# Predicted Stock4 return: -0.05060776151464803
# Buying Stock4 at time 127 with -297.0 shares
# Predicted Stock4 return: -0.016786822023218736
# Buying Stock4 at time 128 with -314.0 shares
# Predicted Stock1 return: -0.0009795683354328498
# Buying Stock1 at time 129 with -447.0 shares
# Predicted Stock4 return: -0.05945590528542082
# Buying Stock4 at time 130 with -306.0 shares
# Predicted Stock4 return: -0.03146665139846942
# Buying Stock4 at time 131 with -317.0 shares
# Predicted Stock4 return: -0.04530825999039528
# Buying Stock4 at time 132 with -316.0 shares
# Predicted Stock4 return: 0.021726206207373932
# Buying Stock4 at time 133 with 337.0 shares
# Predicted Stock4 return: -0.03778749933313125
# Buying Stock4 at time 134 with -327.0 shares
# Predicted Stock4 return: 0.051086352137286
# Buying Stock4 at time 135 with 333.0 shares
# Predicted Stock4 return: 0.015433611124749197
# Buying Stock4 at time 136 with 319.0 shares
# Predicted Stock4 return: -0.005935219926550283
# Buying Stock4 at time 137 with -314.0 shares
# Predicted Stock4 return: -0.0788445413697175
# Buying Stock4 at time 138 with -314.0 shares
# Predicted Stock4 return: -0.01601720106857367
# Buying Stock4 at time 139 with -343.0 shares
# Predicted Stock4 return: -0.0386849305412077
# Buying Stock4 at time 140 with -347.0 shares
# Predicted Stock4 return: -0.0412316835634709
# Buying Stock4 at time 141 with -361.0 shares
# Predicted Stock4 return: 0.022612111561637335
# Buying Stock4 at time 142 with 380.0 shares
# Predicted Stock4 return: -0.003859986001648526
# Buying Stock4 at time 143 with -366.0 shares
# Predicted Stock4 return: 0.1142005201129214
# Buying Stock4 at time 144 with 374.0 shares
# Predicted Stock4 return: -0.05250257787858669
# Buying Stock4 at time 145 with -334.0 shares
# Predicted Stock4 return: -0.16883271042954442
# Buying Stock4 at time 146 with -358.0 shares
# Predicted Stock4 return: -0.06658873111279145
# Buying Stock4 at time 147 with -439.0 shares
# Predicted Stock4 return: -0.12270477097117652
# Buying Stock4 at time 148 with -469.0 shares
# Predicted Stock4 return: 0.027345884809263823
# Buying Stock4 at time 149 with 530.0 shares
# Predicted Stock4 return: 0.008345989622131235
# Buying Stock4 at time 150 with 523.0 shares
# Predicted Stock4 return: 0.010455539894219698
# Buying Stock4 at time 151 with 527.0 shares
# Predicted Stock4 return: 0.045897910186818165
# Buying Stock4 at time 152 with 519.0 shares
# Predicted Stock4 return: -0.16285460491453754
# Buying Stock4 at time 153 with -488.0 shares
# Predicted Stock4 return: -0.008977931933833286
# Buying Stock4 at time 154 with -582.0 shares
# Predicted Stock4 return: -0.0013693661857889306
# Buying Stock4 at time 155 with -597.0 shares
# Predicted Stock4 return: -0.011941122097157197
# Buying Stock4 at time 156 with -597.0 shares
# Predicted Stock4 return: -0.0381679630450523
# Buying Stock4 at time 157 with -611.0 shares
# Predicted Stock4 return: 0.013862377811157718
# Buying Stock4 at time 158 with 621.0 shares
# Predicted Stock4 return: -0.03564872830747278
# Buying Stock4 at time 159 with -603.0 shares
# Predicted Stock2 return: 0.0029359298898699255
# Buying Stock2 at time 160 with 464.0 shares
# Predicted Stock4 return: 0.04266021801342652
# Buying Stock4 at time 161 with 618.0 shares
# Predicted Stock4 return: -0.01787668043058624
# Buying Stock4 at time 162 with -593.0 shares
# Predicted Stock4 return: -0.03354589555927083
# Buying Stock4 at time 163 with -617.0 shares
# Predicted Stock4 return: -0.02340167699399624
# Buying Stock4 at time 164 with -634.0 shares
# Predicted Stock4 return: -0.04586980710002398
# Buying Stock4 at time 165 with -642.0 shares
# Predicted Stock4 return: -0.08534282662229142
# Buying Stock4 at time 166 with -662.0 shares
# Predicted Stock4 return: 0.01134950987128202
# Buying Stock4 at time 167 with 724.0 shares
# Predicted Stock4 return: 0.0032817269023493814
# Buying Stock4 at time 168 with 726.0 shares
# Predicted Stock4 return: -0.0863020015825646
# Buying Stock4 at time 169 with -721.0 shares
# Predicted Stock4 return: -0.07962323845201383
# Buying Stock4 at time 170 with -810.0 shares
# Predicted Stock4 return: -0.09547995177108429
# Buying Stock4 at time 171 with -880.0 shares
# Predicted Stock4 return: 0.03653663667886747
# Buying Stock4 at time 172 with 969.0 shares
# Predicted Stock4 return: -0.00950207947462258
# Buying Stock4 at time 173 with -944.0 shares
# Predicted Stock4 return: 0.00754383434551235
# Buying Stock4 at time 174 with 960.0 shares
# Predicted Stock4 return: -0.06448133601133929
# Buying Stock4 at time 175 with -950.0 shares
# Predicted Stock4 return: -0.017196405761893723
# Buying Stock4 at time 176 with -1004.0 shares
# Predicted Stock4 return: 0.012670497052283273
# Buying Stock4 at time 177 with 1045.0 shares
# Predicted Stock4 return: -0.051335951943496945
# Buying Stock4 at time 178 with -1008.0 shares
# Predicted Stock4 return: 0.05196652537915057
# Buying Stock4 at time 179 with 1066.0 shares
# Predicted Stock4 return: -0.03896551868006383
# Buying Stock4 at time 180 with -1007.0 shares
# Predicted Stock4 return: -0.02233932501065014
# Buying Stock4 at time 181 with -1080.0 shares
# Predicted Stock4 return: -0.020640688942396013
# Buying Stock4 at time 182 with -1087.0 shares
# Predicted Stock4 return: 0.014392654041897287
# Buying Stock4 at time 183 with 1103.0 shares
# Predicted Stock4 return: 0.1536808653766269
# Buying Stock4 at time 184 with 1104.0 shares
# Predicted Stock4 return: 0.023743332698941452
# Buying Stock4 at time 185 with 932.0 shares
# Predicted Stock4 return: -0.006945854858306198
# Buying Stock4 at time 186 with -926.0 shares
# Predicted Stock4 return: -0.0636342379274675
# Buying Stock4 at time 187 with -925.0 shares
# Predicted Stock4 return: 0.011388186740394516
# Buying Stock4 at time 188 with 1034.0 shares
# Predicted Stock4 return: -0.004823721577749797
# Buying Stock4 at time 189 with -1024.0 shares
# Predicted Stock4 return: 0.08605294840663844
# Buying Stock4 at time 190 with 1027.0 shares
# Predicted Stock4 return: -0.07853195084358536
# Buying Stock4 at time 191 with -957.0 shares
# Predicted Stock4 return: 0.011388080269781718
# Buying Stock4 at time 192 with 1039.0 shares
# Predicted Stock4 return: 0.015653038431040912
# Buying Stock4 at time 193 with 1025.0 shares
# Predicted Stock4 return: -0.11401009944676341
# Buying Stock4 at time 194 with -1014.0 shares
# Predicted Stock4 return: -0.08730314683134976
# Buying Stock4 at time 195 with -1128.0 shares
# Predicted Stock4 return: 0.022536494893531867
# Buying Stock4 at time 196 with 1267.0 shares
# Predicted Stock4 return: -0.20845796761209778
# Buying Stock4 at time 197 with -1260.0 shares
# Predicted Stock4 return: -0.007447163687390878
# Buying Stock4 at time 198 with -1557.0 shares
# Predicted Stock4 return: -0.048654680313407715
# Buying Stock4 at time 199 with -1573.0 shares
# Predicted Stock4 return: 0.03506990006134529
# Buying Stock4 at time 200 with 1640.0 shares
# Predicted Stock4 return: -0.0439478541882341
# Buying Stock4 at time 201 with -1570.0 shares
# Predicted Stock4 return: -0.09253516984449922
# Buying Stock4 at time 202 with -1651.0 shares
# Predicted Stock4 return: 0.006293874553856717
# Buying Stock4 at time 203 with 1796.0 shares
# Predicted Stock4 return: -0.060831014925646194
# Buying Stock4 at time 204 with -1738.0 shares
# Predicted Stock4 return: 0.06831922319407949
# Buying Stock4 at time 205 with 1851.0 shares
# Predicted Stock4 return: -0.009626707849734037
# Buying Stock4 at time 206 with -1709.0 shares
# Predicted Stock4 return: -0.007907806434718475
# Buying Stock4 at time 207 with -1741.0 shares
# Predicted Stock4 return: -0.0031748851215350447
# Buying Stock4 at time 208 with -1763.0 shares
# Predicted Stock4 return: 0.018348652317086073
# Buying Stock4 at time 209 with 1799.0 shares
# Predicted Stock4 return: -0.17877060889494778
# Buying Stock4 at time 210 with -1762.0 shares
# Predicted Stock4 return: 0.0667259222301882
# Buying Stock4 at time 211 with 2114.0 shares
# Predicted Stock4 return: 0.05416003590246694
# Buying Stock4 at time 212 with 2007.0 shares
# Predicted Stock4 return: -0.059620141362289346
# Buying Stock4 at time 213 with -1880.0 shares
# Predicted Stock4 return: 0.030881870763698166
# Buying Stock4 at time 214 with 1981.0 shares
# Predicted Stock4 return: 0.06794209487006683
# Buying Stock4 at time 215 with 1928.0 shares
# Predicted Stock4 return: 0.014909021002947196
# Buying Stock4 at time 216 with 1797.0 shares
# Predicted Stock4 return: 0.06054666777166732
# Buying Stock4 at time 217 with 1735.0 shares
# Predicted Stock4 return: 0.06737918610359092
# Buying Stock4 at time 218 with 1692.0 shares
# Predicted Stock4 return: -0.031099096460593903
# Buying Stock4 at time 219 with -1632.0 shares
# Predicted Stock4 return: -0.2396614015437172
# Buying Stock4 at time 220 with -1665.0 shares
# Predicted Stock4 return: -0.00362390137002851
# Buying Stock4 at time 221 with -2072.0 shares
# Predicted Stock4 return: 0.05205791108500954
# Buying Stock4 at time 222 with 2138.0 shares
# Predicted Stock4 return: 0.017946736935171938
# Buying Stock4 at time 223 with 2112.0 shares
# Predicted Stock4 return: -0.04372196007715345
# Buying Stock4 at time 224 with -2068.0 shares
# Predicted Stock4 return: -0.010527511405114478
# Buying Stock4 at time 225 with -2096.0 shares
# Predicted Stock4 return: 0.006303139991181565
# Buying Stock4 at time 226 with 2129.0 shares
# Predicted Stock4 return: 0.07061294445005531
# Buying Stock4 at time 227 with 2098.0 shares
# Predicted Stock4 return: -0.06958490895085942
# Buying Stock4 at time 228 with -2011.0 shares
# Predicted Stock4 return: -0.02261713195571156
# Buying Stock4 at time 229 with -2179.0 shares
# Predicted Stock4 return: 0.02184997773616695
# Buying Stock4 at time 230 with 2230.0 shares
# Predicted Stock4 return: -0.006647290446504113
# Buying Stock4 at time 231 with -2225.0 shares
# Predicted Stock4 return: 0.015371073874062127
# Buying Stock4 at time 232 with 2273.0 shares
# Predicted Stock4 return: -0.11456747670443954
# Buying Stock4 at time 233 with -2245.0 shares
# Predicted Stock4 return: -0.11607903633213595
# Buying Stock4 at time 234 with -2474.0 shares
# Predicted Stock4 return: 0.04227535429614523
# Buying Stock4 at time 235 with 2824.0 shares
# Predicted Stock4 return: -0.03871952935704475
# Buying Stock4 at time 236 with -2817.0 shares
# Predicted Stock4 return: -0.007550341920950238
# Buying Stock4 at time 237 with -2939.0 shares
# Predicted Stock4 return: 0.06655155767011425
# Buying Stock4 at time 238 with 2981.0 shares
# Predicted Stock4 return: 0.058697201065124736
# Buying Stock4 at time 239 with 2791.0 shares
# Predicted Stock4 return: -0.011425463805704356
# Buying Stock4 at time 240 with -2686.0 shares
# Predicted Stock4 return: -0.04690710871998383
# Buying Stock4 at time 241 with -2833.0 shares
# Predicted Stock4 return: -0.027461050880000122
# Buying Stock4 at time 242 with -3002.0 shares
# Predicted Stock4 return: 0.08342407080324021
# Buying Stock4 at time 243 with 3082.0 shares
# Predicted Stock4 return: -0.0032082951798885146
# Buying Stock4 at time 244 with -2766.0 shares
# Predicted Stock4 return: -0.029171625429280597
# Buying Stock4 at time 245 with -2756.0 shares
# Predicted Stock4 return: -0.03395004859542729
# Buying Stock4 at time 246 with -2867.0 shares
# Predicted Stock4 return: -0.07728898374450224
# Buying Stock4 at time 247 with -3036.0 shares
# Predicted Stock4 return: -0.0014891241635835066
# Buying Stock4 at time 248 with -3315.0 shares
# Predicted Stock4 return: -0.05397269026401564
# Buying Stock4 at time 249 with -3231.0 shares
# Predicted Stock4 return: 0.03063180134433947
# Buying Stock4 at time 250 with 3368.0 shares
# Predicted Stock4 return: -0.15510837550324472
# Buying Stock4 at time 251 with -3276.0 shares
# Predicted Stock4 return: 0.017201919177112585
# Buying Stock4 at time 252 with 3980.0 shares
# Predicted Stock4 return: 0.018503675742532578
# Buying Stock4 at time 253 with 3934.0 shares
# Predicted Stock4 return: 0.05328498604556537
# Buying Stock4 at time 254 with 3987.0 shares
# Predicted Stock4 return: -0.0041043744973523425
# Buying Stock4 at time 255 with -3862.0 shares
# Predicted Stock4 return: -0.024093408136495575
# Buying Stock4 at time 256 with -3660.0 shares
# Predicted Stock4 return: 0.033276656310248245
# Buying Stock4 at time 257 with 3786.0 shares
# Predicted Stock4 return: -0.056680448360122926
# Buying Stock4 at time 258 with -3595.0 shares
# Predicted Stock4 return: -0.00802593082603958
# Buying Stock4 at time 259 with -3761.0 shares
# Predicted Stock4 return: 0.008936539975962644
# Buying Stock4 at time 260 with 3853.0 shares
# Predicted Stock4 return: -0.06544001973764457
# Buying Stock4 at time 261 with -3796.0 shares
# Predicted Stock4 return: -0.1277761789027797
# Buying Stock4 at time 262 with -3962.0 shares
# Predicted Stock4 return: -0.05910751829975805
# Buying Stock4 at time 263 with -4487.0 shares
# Predicted Stock4 return: -0.03252831252688479
# Buying Stock4 at time 264 with -4755.0 shares
# Predicted Stock4 return: 0.12082091097676034
# Buying Stock4 at time 265 with 4944.0 shares
# Predicted Stock4 return: 0.0355575338301622
# Buying Stock4 at time 266 with 4360.0 shares
# Predicted Stock4 return: 0.055594884565945024
# Buying Stock4 at time 267 with 4382.0 shares
# Predicted Stock4 return: -0.013706370403360257
# Buying Stock4 at time 268 with -4238.0 shares
# Predicted Stock4 return: -0.06207419826920282
# Buying Stock4 at time 269 with -4345.0 shares
# Predicted Stock4 return: -0.050364097399100166
# Buying Stock4 at time 270 with -4452.0 shares
# Predicted Stock4 return: -0.07136068691946526
# Buying Stock4 at time 271 with -4593.0 shares
# Predicted Stock4 return: 0.04086436518387114
# Buying Stock4 at time 272 with 4984.0 shares
# Predicted Stock4 return: -0.048692090796900615
# Buying Stock4 at time 273 with -4879.0 shares
# Predicted Stock4 return: -0.009831406510264035
# Buying Stock4 at time 274 with -5136.0 shares
# Predicted Stock4 return: -0.021638256383004893
# Buying Stock4 at time 275 with -5093.0 shares
# Predicted Stock4 return: 0.0067806104820072426
# Buying Stock4 at time 276 with 5288.0 shares
# Predicted Stock4 return: 0.07194361936625035
# Buying Stock4 at time 277 with 5432.0 shares
# Predicted Stock4 return: -0.02511516006873046
# Buying Stock4 at time 278 with -5106.0 shares
# Predicted Stock4 return: -0.04042489508690473
# Buying Stock4 at time 279 with -5266.0 shares
# Predicted Stock4 return: -0.008089644731531457
# Buying Stock4 at time 280 with -5352.0 shares
# Predicted Stock4 return: 0.08945681817233428
# Buying Stock4 at time 281 with 5079.0 shares
# Predicted Stock4 return: -0.06268376443457041
# Buying Stock4 at time 282 with -4656.0 shares
# Predicted Stock4 return: 0.012027758307482535
# Buying Stock4 at time 283 with 4789.0 shares
# Predicted Stock4 return: 0.10734549162222601
# Buying Stock4 at time 284 with 4797.0 shares
# Predicted Stock4 return: 0.005464444267983551
# Buying Stock4 at time 285 with 4321.0 shares
# Predicted Stock4 return: -0.11981939675228934
# Buying Stock4 at time 286 with -4468.0 shares
# Predicted Stock4 return: 0.051828409759799264
# Buying Stock4 at time 287 with 4974.0 shares
# Predicted Stock4 return: 0.03693310921963491
# Buying Stock4 at time 288 with 4723.0 shares
# Predicted Stock4 return: 0.019006695746353497
# Buying Stock4 at time 289 with 4509.0 shares
# Predicted Stock4 return: 0.04520483010244424
# Buying Stock4 at time 290 with 4546.0 shares
# Predicted Stock4 return: -0.019848394188706785
# Buying Stock4 at time 291 with -4440.0 shares
# Predicted Stock4 return: 0.003718299710123661
# Buying Stock4 at time 292 with 4568.0 shares
# Predicted Stock4 return: 0.05392383230129688
# Buying Stock4 at time 293 with 4533.0 shares
# Predicted Stock4 return: 0.016804851912686748
# Buying Stock4 at time 294 with 4450.0 shares
# Predicted Stock4 return: -0.04207673505392235
# Buying Stock4 at time 295 with -4307.0 shares
# Predicted Stock4 return: -0.002828485805224378
# Buying Stock4 at time 296 with -4445.0 shares
# Predicted Stock4 return: -0.030764088719893584
# Buying Stock4 at time 297 with -4437.0 shares
# Predicted Stock4 return: 0.2447843858305315
# Buying Stock4 at time 298 with 4560.0 shares
# Predicted Stock4 return: 0.030692795014232183
# Buying Stock4 at time 299 with 3647.0 shares
# Predicted Stock4 return: 0.03894457847078765
# Buying Stock4 at time 300 with 3541.0 shares
# Predicted Stock4 return: 0.11542767582817962
# Buying Stock4 at time 301 with 3369.0 shares
# Predicted Stock4 return: -0.18894713571761448
# Buying Stock4 at time 302 with -2961.0 shares
# Predicted Stock4 return: 0.06899887548651584
# Buying Stock4 at time 303 with 3617.0 shares
# Predicted Stock4 return: -0.040630358416128685
# Buying Stock4 at time 304 with -3398.0 shares
# Predicted Stock4 return: 0.038522168698757554
# Buying Stock4 at time 305 with 3558.0 shares
# Predicted Stock4 return: 0.048939015527554475
# Buying Stock4 at time 306 with 3468.0 shares
# Predicted Stock4 return: 0.018924661210258726
# Buying Stock4 at time 307 with 3335.0 shares
# Predicted Stock4 return: 0.011535732635329421
# Buying Stock4 at time 308 with 3312.0 shares
# Predicted Stock4 return: 0.05149637175401175
# Buying Stock4 at time 309 with 3227.0 shares
# Predicted Stock4 return: 0.040609515717315234
# Buying Stock4 at time 310 with 3126.0 shares
# Predicted Stock4 return: -0.014503860659236676
# Buying Stock4 at time 311 with -2910.0 shares
# Predicted Stock4 return: -0.1659445791844963
# Buying Stock4 at time 312 with -2935.0 shares
# Predicted Stock4 return: -0.0780720227151272
# Buying Stock4 at time 313 with -3406.0 shares
# Predicted Stock4 return: 0.009380018242867192
# Buying Stock4 at time 314 with 3807.0 shares
# Predicted Stock4 return: 0.06164560853626136
# Buying Stock4 at time 315 with 3724.0 shares
# Predicted Stock4 return: 0.0037168873357696845
# Buying Stock4 at time 316 with 3471.0 shares
# Predicted Stock4 return: -0.15163434976433623
# Buying Stock4 at time 317 with -3394.0 shares
# Predicted Stock4 return: -0.0010802493159651457
# Buying Stock4 at time 318 with -4029.0 shares
# Predicted Stock4 return: 0.025529299312810397
# Buying Stock4 at time 319 with 4161.0 shares
# Predicted Stock4 return: -0.03509310026148001
# Buying Stock4 at time 320 with -4157.0 shares
# Predicted Stock4 return: -0.1123471303733278
# Buying Stock4 at time 321 with -4273.0 shares
# Predicted Stock4 return: 0.08589613487513226
# Buying Stock4 at time 322 with 4657.0 shares
# Predicted Stock4 return: 0.0010989362025706434
# Buying Stock4 at time 323 with 4332.0 shares
# Predicted Stock4 return: 0.06702135683683158
# Buying Stock4 at time 324 with 4510.0 shares
# Predicted Stock4 return: 0.012876914988794548
# Buying Stock4 at time 325 with 4258.0 shares
# Predicted Stock4 return: -0.046431451059386473
# Buying Stock4 at time 326 with -4249.0 shares
# Predicted Stock4 return: -0.03424991558467724
# Buying Stock4 at time 327 with -4431.0 shares
# Predicted Stock4 return: 0.07271173301697015
# Buying Stock4 at time 328 with 4554.0 shares
# Predicted Stock4 return: -0.004133682455671425
# Buying Stock4 at time 329 with -4242.0 shares
# Predicted Stock4 return: 0.013751735143552948
# Buying Stock4 at time 330 with 4222.0 shares
# Predicted Stock4 return: 0.08266649615010402
# Buying Stock4 at time 331 with 4074.0 shares
# Predicted Stock4 return: -0.16662088980017284
# Buying Stock4 at time 332 with -3664.0 shares
# Predicted Stock4 return: 0.01332789705672569
# Buying Stock4 at time 333 with 4325.0 shares
# Predicted Stock4 return: 0.001971559474972506
# Buying Stock4 at time 334 with 4326.0 shares
# Predicted Stock4 return: -0.12293361388077712
# Buying Stock4 at time 335 with -4340.0 shares
# Predicted Stock4 return: 0.029536609596069477
# Buying Stock4 at time 336 with 4990.0 shares
# Predicted Stock4 return: 0.13144127932064237
# Buying Stock4 at time 337 with 4907.0 shares
# Predicted Stock4 return: -0.003702968667710257
# Buying Stock4 at time 338 with -4463.0 shares
# Predicted Stock4 return: -0.013308708694670095
# Buying Stock4 at time 339 with -4477.0 shares
# Predicted Stock4 return: 0.012015765443243016
# Buying Stock4 at time 340 with 4496.0 shares
# Predicted Stock4 return: 0.04345290378622193
# Buying Stock4 at time 341 with 4498.0 shares
# Predicted Stock4 return: -0.012427715854588666
# Buying Stock4 at time 342 with -4337.0 shares
# Predicted Stock4 return: 0.05522272204646286
# Buying Stock4 at time 343 with 4336.0 shares
# Predicted Stock4 return: -0.09746436637876937
# Buying Stock4 at time 344 with -4164.0 shares
# Predicted Stock4 return: 0.014638725201995804
# Buying Stock4 at time 345 with 4605.0 shares
# Predicted Stock4 return: 0.026428484900642785
# Buying Stock4 at time 346 with 4768.0 shares
# Predicted Stock4 return: 0.030785998613796887
# Buying Stock4 at time 347 with 4656.0 shares
# Predicted Stock4 return: 0.01157315583616083
# Buying Stock4 at time 348 with 4593.0 shares
# Predicted Stock4 return: 0.0015363856604553342
# Buying Stock4 at time 349 with 4483.0 shares
# Predicted Stock4 return: -0.022026400992545766
# Buying Stock4 at time 350 with -4530.0 shares
# Predicted Stock4 return: -0.0752913466554842
# Buying Stock4 at time 351 with -4613.0 shares
# Predicted Stock4 return: 0.026445145758100676
# Buying Stock4 at time 352 with 5113.0 shares
# Predicted Stock4 return: 0.07231032688327288
# Buying Stock4 at time 353 with 5001.0 shares
# Predicted Stock4 return: -0.06436433006335207
# Buying Stock4 at time 354 with -4760.0 shares
# Predicted Stock4 return: -0.04215390330671387
# Buying Stock4 at time 355 with -5064.0 shares
# Predicted Stock4 return: 0.09246783518349785
# Buying Stock4 at time 356 with 5321.0 shares
# Predicted Stock4 return: 0.0945285095054762
# Buying Stock4 at time 357 with 4703.0 shares
# Predicted Stock4 return: 0.09701638633167026
# Buying Stock4 at time 358 with 4219.0 shares
# Predicted Stock4 return: -0.025451178719906237
# Buying Stock4 at time 359 with -3821.0 shares
# Predicted Stock4 return: -0.06117814514446219
# Buying Stock4 at time 360 with -4017.0 shares
# Predicted Stock4 return: -0.0577543859306446
# Buying Stock4 at time 361 with -4168.0 shares
# Predicted Stock4 return: 0.031646570099852916
# Buying Stock4 at time 362 with 4448.0 shares
# Predicted Stock4 return: 0.13762879041987203
# Buying Stock4 at time 363 with 4314.0 shares
# Predicted Stock4 return: -0.01587110503461976
# Buying Stock4 at time 364 with -3668.0 shares
# Predicted Stock4 return: 0.011119286855102627
# Buying Stock4 at time 365 with 3558.0 shares
# Predicted Stock4 return: -0.022404954200358915
# Buying Stock4 at time 366 with -3527.0 shares
# Predicted Stock4 return: -0.01588201884129633
# Buying Stock4 at time 367 with -3608.0 shares
# Predicted Stock4 return: 0.08910835930564298
# Buying Stock4 at time 368 with 3683.0 shares
# Predicted Stock4 return: 0.07333176517243017
# Buying Stock4 at time 369 with 3316.0 shares
# Predicted Stock4 return: -0.06451973984673029
# Buying Stock4 at time 370 with -3049.0 shares
# Predicted Stock4 return: -0.01325126889715893
# Buying Stock4 at time 371 with -3333.0 shares
# Predicted Stock4 return: -0.2003869976954604
# Buying Stock4 at time 372 with -3399.0 shares
# Predicted Stock4 return: 0.005464517602135332
# Buying Stock4 at time 373 with 4222.0 shares
# Predicted Stock4 return: -0.1451430539613945
# Buying Stock4 at time 374 with -4168.0 shares
# Predicted Stock4 return: -0.1327941671124195
# Buying Stock4 at time 375 with -4830.0 shares
# Predicted Stock4 return: -0.2694412760912061
# Buying Stock4 at time 376 with -5416.0 shares
# Predicted Stock4 return: 0.06448478041557773
# Buying Stock4 at time 377 with 7109.0 shares
# Predicted Stock4 return: -0.005516179860877622
# Buying Stock4 at time 378 with -6602.0 shares
# Predicted Stock4 return: -0.1511424485844959
# Buying Stock4 at time 379 with -6655.0 shares
# Predicted Stock4 return: 0.010337777121013959
# Buying Stock4 at time 380 with 7929.0 shares
# Predicted Stock4 return: -0.06330251551392341
# Buying Stock4 at time 381 with -7737.0 shares
# Predicted Stock4 return: -0.021437100517211653
# Buying Stock4 at time 382 with -8258.0 shares
# Predicted Stock4 return: 0.020061601235472622
# Buying Stock4 at time 383 with 8241.0 shares
# Predicted Stock4 return: 0.03639134848277881
# Buying Stock4 at time 384 with 8135.0 shares
# Predicted Stock4 return: -0.03687081786981251
# Buying Stock4 at time 385 with -7842.0 shares
# Predicted Stock4 return: 0.037719477419114134
# Buying Stock4 at time 386 with 8163.0 shares
# Predicted Stock4 return: 0.17096649897565738
# Buying Stock4 at time 387 with 7932.0 shares
# Predicted Stock4 return: -0.07990467820439393
# Buying Stock4 at time 388 with -6519.0 shares
# Predicted Stock4 return: 0.03633452624522739
# Buying Stock4 at time 389 with 7065.0 shares
# Predicted Stock4 return: -0.01786130814726043
# Buying Stock4 at time 390 with -6910.0 shares
# Predicted Stock4 return: 0.029278501071465804
# Buying Stock4 at time 391 with 7045.0 shares
# Predicted Stock4 return: -0.021383307833517363
# Buying Stock4 at time 392 with -7202.0 shares
# Predicted Stock4 return: -0.04474523464618738
# Buying Stock4 at time 393 with -7371.0 shares
# Predicted Stock4 return: -0.01788340673080051
# Buying Stock4 at time 394 with -7690.0 shares
# Predicted Stock4 return: 0.11928681314637679
# Buying Stock4 at time 395 with 7439.0 shares
# Predicted Stock4 return: 0.03366227520128281
# Buying Stock4 at time 396 with 6727.0 shares
# Predicted Stock4 return: 0.004602002920405852
# Buying Stock4 at time 397 with 6477.0 shares
# Predicted Stock4 return: -0.012561263356819334
# Buying Stock4 at time 398 with -6589.0 shares
# Predicted Stock4 return: 0.055664385205062214
# Buying Stock4 at time 399 with 6489.0 shares
# Predicted Stock4 return: 0.15898359179720162
# Buying Stock4 at time 400 with 6377.0 shares
# Predicted Stock4 return: 0.05900732014398973
# Buying Stock4 at time 401 with 5497.0 shares
# Predicted Stock4 return: -0.037490232192064134
# Buying Stock4 at time 402 with -5029.0 shares
# Predicted Stock4 return: -0.1743850761637727
# Buying Stock4 at time 403 with -5239.0 shares
# Predicted Stock4 return: 0.050349572011527156
# Buying Stock4 at time 404 with 6422.0 shares
# Predicted Stock4 return: -0.03496068463605343
# Buying Stock4 at time 405 with -5890.0 shares
# Predicted Stock4 return: 0.05650077498846319
# Buying Stock4 at time 406 with 6001.0 shares
# Predicted Stock4 return: -0.039786024807733786
# Buying Stock4 at time 407 with -5638.0 shares
# Predicted Stock4 return: 0.04417925536251111
# Buying Stock4 at time 408 with 5993.0 shares
# Predicted Stock4 return: 0.0735988018001428
# Buying Stock4 at time 409 with 5787.0 shares
# Predicted Stock4 return: 0.04937741681909029
# Buying Stock4 at time 410 with 5537.0 shares
# Predicted Stock4 return: -0.09016037478051256
# Buying Stock4 at time 411 with -5292.0 shares
# Predicted Stock4 return: 0.010310961820822487
# Buying Stock4 at time 412 with 5948.0 shares
# Predicted Stock4 return: -0.03493560306687796
# Buying Stock4 at time 413 with -5990.0 shares
# Predicted Stock4 return: 0.032730786985984014
# Buying Stock4 at time 414 with 6086.0 shares
# Predicted Stock4 return: -0.06042243765434165
# Buying Stock4 at time 415 with -5970.0 shares
# Predicted Stock4 return: 0.0032817269023493814
# Buying Stock4 at time 416 with 6438.0 shares
# Predicted Stock4 return: -0.2016512223573275
# Buying Stock4 at time 417 with -6200.0 shares
# Predicted Stock4 return: 0.03239840910292116
# Buying Stock4 at time 418 with 7688.0 shares
# Predicted Stock4 return: 0.11616856889582594
# Buying Stock4 at time 419 with 7568.0 shares
# Predicted Stock4 return: -0.0033212634006312544
# Buying Stock4 at time 420 with -6698.0 shares
# Predicted Stock4 return: -0.03986219461540354
# Buying Stock4 at time 421 with -6802.0 shares
# Predicted Stock4 return: -0.04561784079075554
# Buying Stock4 at time 422 with -7054.0 shares
# Predicted Stock4 return: 0.03458338842016373
# Buying Stock4 at time 423 with 6956.0 shares
# Predicted Stock4 return: 0.07554933801289448
# Buying Stock4 at time 424 with 6483.0 shares
# Predicted Stock4 return: -0.009042936423356207
# Buying Stock4 at time 425 with -5968.0 shares
# Predicted Stock4 return: 0.05170923390042122
# Buying Stock4 at time 426 with 5911.0 shares
# Predicted Stock4 return: 0.0019619604638876588
# Buying Stock4 at time 427 with 5606.0 shares
# Predicted Stock4 return: -0.10318159515417905
# Buying Stock4 at time 428 with -5650.0 shares
# Predicted Stock4 return: 0.023992426199358447
# Buying Stock4 at time 429 with 6198.0 shares
# Predicted Stock4 return: 0.07508530511629136
# Buying Stock4 at time 430 with 6017.0 shares
# Predicted Stock4 return: 0.001961647610759183
# Buying Stock4 at time 431 with 5592.0 shares
# Predicted Stock4 return: 0.0455251225654531
# Buying Stock4 at time 432 with 5676.0 shares
# Predicted Stock4 return: -0.018265995698371375
# Buying Stock4 at time 433 with -5579.0 shares
# Predicted Stock4 return: 0.03583398192628136
# Buying Stock4 at time 434 with 5732.0 shares
# Predicted Stock4 return: 0.00240237682095979
# Buying Stock4 at time 435 with 5630.0 shares
# Predicted Stock4 return: 0.02878322442558114
# Buying Stock4 at time 436 with 5599.0 shares
# Predicted Stock4 return: -0.06923717159029788
# Buying Stock4 at time 437 with -5457.0 shares
# Predicted Stock4 return: -0.030158243444375087
# Buying Stock4 at time 438 with -5935.0 shares
# Predicted Stock4 return: 0.060511132719451265
# Buying Stock4 at time 439 with 5914.0 shares
# Predicted Stock4 return: -0.059615214953555824
# Buying Stock4 at time 440 with -5503.0 shares
# Predicted Stock4 return: 0.11422850200701193
# Buying Stock4 at time 441 with 5872.0 shares
# Predicted Stock4 return: 0.06041860179995007
# Buying Stock4 at time 442 with 5074.0 shares
# Predicted Stock4 return: -0.04502237831444924
# Buying Stock4 at time 443 with -4732.0 shares
# Predicted Stock4 return: 0.03492248429357532
# Buying Stock4 at time 444 with 4962.0 shares
# Predicted Stock4 return: -0.0006714425136810243
# Buying Stock4 at time 445 with -4806.0 shares
# Predicted Stock4 return: -0.005064360813699327
# Buying Stock4 at time 446 with -4822.0 shares
# Predicted Stock4 return: 0.019976046944268626
# Buying Stock4 at time 447 with 4907.0 shares
# Predicted Stock4 return: 0.010309108533171865
# Buying Stock4 at time 448 with 4765.0 shares
# Predicted Stock4 return: 0.02567908322165474
# Buying Stock4 at time 449 with 4740.0 shares
# Predicted Stock4 return: 0.025671364587889923
# Buying Stock4 at time 450 with 4640.0 shares
# Predicted Stock4 return: 0.17399875788117697
# Buying Stock4 at time 451 with 4648.0 shares
# Predicted Stock4 return: 0.08688454602124385
# Buying Stock4 at time 452 with 3978.0 shares
# Predicted Stock4 return: -0.0015269072983470234
# Buying Stock4 at time 453 with -3717.0 shares
# Predicted Stock4 return: -0.08852626662126234
# Buying Stock4 at time 454 with -3684.0 shares
# Predicted Stock4 return: 0.061071271743004765
# Buying Stock4 at time 455 with 3980.0 shares
# Predicted Stock4 return: -0.015089514330471274
# Buying Stock4 at time 456 with -3800.0 shares
# Predicted Stock4 return: 0.0829129563261683
# Buying Stock4 at time 457 with 3920.0 shares
# Predicted Stock4 return: -0.022064192103005514
# Buying Stock4 at time 458 with -3652.0 shares
# Predicted Stock4 return: 0.06404823937768234
# Buying Stock4 at time 459 with 3707.0 shares
# Predicted Stock4 return: 0.012016939759858125
# Buying Stock4 at time 460 with 3418.0 shares
# Predicted Stock4 return: 0.07053382366723901
# Buying Stock4 at time 461 with 3411.0 shares
# Predicted Stock4 return: 0.06610177634955636
# Buying Stock4 at time 462 with 3206.0 shares
# Predicted Stock4 return: -0.03463538978716424
# Buying Stock4 at time 463 with -3047.0 shares
# Predicted Stock1 return: -0.0013792737124165891
# Buying Stock1 at time 464 with -610.0 shares
# Predicted Stock4 return: 0.04253055333162905
# Buying Stock4 at time 465 with 3146.0 shares
# Predicted Stock4 return: -0.04117342013632488
# Buying Stock4 at time 466 with -3058.0 shares
# Predicted Stock4 return: -0.020705599190096322
# Buying Stock4 at time 467 with -3200.0 shares
# Predicted Stock4 return: 0.07134363579084543
# Buying Stock4 at time 468 with 3299.0 shares
# Predicted Stock4 return: 0.0935001305248574
# Buying Stock4 at time 469 with 3037.0 shares
# Predicted Stock4 return: 0.1730227191210657
# Buying Stock4 at time 470 with 2803.0 shares
# Predicted Stock4 return: 0.163898415620971
# Buying Stock4 at time 471 with 2327.0 shares
# Predicted Stock4 return: -0.01014216020275161
# Buying Stock4 at time 472 with -2053.0 shares
# Predicted Stock4 return: -0.03483266657357731
# Buying Stock4 at time 473 with -2121.0 shares
# Predicted Stock4 return: 0.02668383377009804
# Buying Stock4 at time 474 with 2209.0 shares
# Predicted Stock4 return: 0.1276148055955497
# Buying Stock4 at time 475 with 2120.0 shares
# Predicted Stock4 return: 0.05733032960140018
# Buying Stock4 at time 476 with 1931.0 shares
# Predicted Stock4 return: 0.024019138490610506
# Buying Stock4 at time 477 with 1856.0 shares
# Predicted Stock4 return: -0.042498777612548014
# Buying Stock4 at time 478 with -1847.0 shares
# Predicted Stock4 return: 0.06638235773949677
# Buying Stock4 at time 479 with 1917.0 shares
# Predicted Stock4 return: 0.06588935408097962
# Buying Stock4 at time 480 with 1814.0 shares
# Predicted Stock4 return: -0.02648218580636496
# Buying Stock4 at time 481 with -1724.0 shares
# Predicted Stock4 return: 0.0619737186444213
# Buying Stock4 at time 482 with 1764.0 shares
# Predicted Stock4 return: 0.035188251303331086
# Buying Stock4 at time 483 with 1656.0 shares
# Predicted Stock4 return: 0.15670263334768533
# Buying Stock4 at time 484 with 1661.0 shares
# Predicted Stock4 return: 0.07981145799315126
# Buying Stock4 at time 485 with 1434.0 shares
# Predicted Stock4 return: 0.00070510817296167
# Buying Stock4 at time 486 with 1341.0 shares
# Predicted Stock4 return: -0.011319691648465215
# Buying Stock4 at time 487 with -1331.0 shares
# Predicted Stock4 return: 0.006718127113297433
# Buying Stock4 at time 488 with 1389.0 shares
# Predicted Stock4 return: 0.04022107532754568
# Buying Stock4 at time 489 with 1384.0 shares
# Predicted Stock4 return: -0.12807894106055717
# Buying Stock4 at time 490 with -1335.0 shares
# Predicted Stock4 return: -0.05220800487086771
# Buying Stock4 at time 491 with -1511.0 shares
# Predicted Stock4 return: -0.07248991059858445
# Buying Stock4 at time 492 with -1589.0 shares
# Predicted Stock4 return: -0.17645501508138098
# Buying Stock4 at time 493 with -1750.0 shares
# Predicted Stock4 return: -0.004930436072350542
# Buying Stock4 at time 494 with -2053.0 shares
# Predicted Stock4 return: -0.020061055285828324
# Buying Stock4 at time 495 with -2062.0 shares
# Predicted Stock4 return: 0.0417679179724639
# Buying Stock4 at time 496 with 2100.0 shares
# Predicted Stock4 return: -0.06889118109243941
# Buying Stock4 at time 497 with -1965.0 shares
# Predicted Stock4 return: -0.00623665520605159
# Buying Stock4 at time 498 with -2113.0 shares
# Predicted Stock4 return: -0.03696096604706999
# Buying Stock4 at time 499 with -2197.0 shares
# Predicted Stock4 return: -0.015769627498169264
# Buying Stock4 at time 500 with -2337.0 shares
# Predicted Stock4 return: 0.06305122884627573
# Buying Stock4 at time 501 with 2388.0 shares
# Predicted Stock4 return: 0.13223057234023264
# Buying Stock4 at time 502 with 2130.0 shares
# Predicted Stock4 return: -0.051132267919074124
# Buying Stock4 at time 503 with -1838.0 shares
# Predicted Stock4 return: -0.06760220614243043
# Buying Stock4 at time 504 with -1887.0 shares
# Predicted Stock4 return: 0.04568546365933486
# Buying Stock4 at time 505 with 2040.0 shares
# Predicted Stock4 return: 0.03744203525041381
# Buying Stock4 at time 506 with 1917.0 shares
# Predicted Stock4 return: -0.05246971580654036
# Buying Stock4 at time 507 with -1842.0 shares
# Predicted Stock4 return: 0.06297402886105502
# Buying Stock4 at time 508 with 1925.0 shares
# Predicted Stock4 return: 0.02618598713666013
# Buying Stock4 at time 509 with 1833.0 shares
# Predicted Stock4 return: -0.021342475639981026
# Buying Stock4 at time 510 with -1799.0 shares
# Predicted Stock4 return: -0.024376983637357776
# Buying Stock4 at time 511 with -1890.0 shares
# Predicted Stock4 return: 0.0071728896348995505
# Buying Stock4 at time 512 with 1974.0 shares
# Predicted Stock4 return: -0.03735687211484674
# Buying Stock4 at time 513 with -1938.0 shares
# Predicted Stock4 return: -0.06160769039691764
# Buying Stock4 at time 514 with -2033.0 shares
# Predicted Stock1 return: -0.0009784710935987824
# Buying Stock1 at time 515 with -627.0 shares
# Predicted Stock4 return: -0.05647861203394022
# Buying Stock4 at time 516 with -2249.0 shares
# Predicted Stock4 return: -0.028359731205656914
# Buying Stock4 at time 517 with -2352.0 shares
# Predicted Stock4 return: -0.030977083963527545
# Buying Stock4 at time 518 with -2515.0 shares
# Predicted Stock4 return: 0.037124727805898164
# Buying Stock4 at time 519 with 2560.0 shares
# Predicted Stock4 return: 0.019760758579806758
# Buying Stock4 at time 520 with 2508.0 shares
# Predicted Stock4 return: 0.12337473352602499
# Buying Stock4 at time 521 with 2455.0 shares
# Predicted Stock4 return: -0.024846947281642506
# Buying Stock4 at time 522 with -2133.0 shares
# Predicted Stock4 return: -0.03914602823082588
# Buying Stock4 at time 523 with -2302.0 shares
# Predicted Stock4 return: -0.04697169923174574
# Buying Stock4 at time 524 with -2434.0 shares
# Predicted Stock4 return: 0.11253747268896444
# Buying Stock4 at time 525 with 2611.0 shares
# Predicted Stock4 return: -0.09799971503337629
# Buying Stock4 at time 526 with -2292.0 shares
# Predicted Stock4 return: -0.057408619562714494
# Buying Stock4 at time 527 with -2555.0 shares
# Predicted Stock4 return: -0.20412620597398687
# Buying Stock4 at time 528 with -2742.0 shares
# Predicted Stock4 return: 0.10296484706192746
# Buying Stock4 at time 529 with 3359.0 shares
# ...
# Predicted Stock4 return: 0.03232332593316816
# Buying Stock4 at time 656 with 404.0 shares
# Predicted Stock4 return: 0.09162970979119353
# Buying Stock4 at time 657 with 380.0 shares
# Predicted Stock4 return: -0.13116094801765218
# Buying Stock4 at time 658 with -343.0 shares
# Predicted Stock4 return: -0.15375297566548
# Buying Stock4 at time 659 with -384.0 shares
# Predicted Stock4 return: 0.05434670770063921
# Buying Stock4 at time 660 with 451.0 shares
# Predicted Stock4 return: -0.010212455048433957
# Buying Stock4 at time 661 with -424.0 shares
# Predicted Stock4 return: -0.07854374658624699
# Buying Stock4 at time 662 with -437.0 shares
# Predicted Stock4 return: -0.0009413998779730466
# Buying Stock4 at time 663 with -478.0 shares
# Predicted Stock4 return: 0.011306189395873353
# Buying Stock4 at time 664 with 483.0 shares
# Predicted Stock4 return: -0.044436814068906726
# Buying Stock4 at time 665 with -486.0 shares
# Predicted Stock4 return: -0.10025487275648107
# Buying Stock4 at time 666 with -516.0 shares
# Predicted Stock4 return: -0.08602885732700202
# Buying Stock4 at time 667 with -581.0 shares
# Predicted Stock4 return: -0.002228395560121708
# Buying Stock4 at time 668 with -634.0 shares
# Predicted Stock4 return: 0.015574581132310281
# Buying Stock4 at time 669 with 589.0 shares
# Predicted Stock4 return: 0.014300821608647414
# Buying Stock4 at time 670 with 577.0 shares
# Predicted Stock4 return: -0.022142641050735098
# Buying Stock4 at time 671 with -572.0 shares
# Predicted Stock4 return: 0.04991131585930573
# Buying Stock4 at time 672 with 590.0 shares
# Predicted Stock4 return: -0.05009204002339151
# Buying Stock4 at time 673 with -572.0 shares
# Predicted Stock4 return: 0.41027335534834036
# Buying Stock4 at time 674 with 610.0 shares
# Predicted Stock4 return: 0.04920455403185511
# Buying Stock4 at time 675 with 391.0 shares
# Predicted Stock4 return: 0.005807803397377619
# Buying Stock4 at time 676 with 370.0 shares
# Predicted Stock4 return: 0.09674292330606418
# Buying Stock4 at time 677 with 367.0 shares
# Predicted Stock4 return: 0.05709185447663218
# Buying Stock4 at time 678 with 337.0 shares
# Predicted Stock4 return: 0.10787261345965027
# Buying Stock4 at time 679 with 324.0 shares
# Predicted Stock4 return: 0.07331628189109587
# Buying Stock4 at time 680 with 286.0 shares
# Predicted Stock4 return: 0.02590324546272841
# Buying Stock4 at time 681 with 283.0 shares
# Predicted Stock4 return: -0.06958446150417757
# Buying Stock4 at time 682 with -276.0 shares
# Predicted Stock4 return: -0.18747311113871895
# Buying Stock4 at time 683 with -291.0 shares
# Predicted Stock4 return: 0.04070408783590802
# Buying Stock4 at time 684 with 352.0 shares
# Predicted Stock4 return: 0.0810249998556172
# Buying Stock4 at time 685 with 334.0 shares
# Predicted Stock4 return: -0.05715962996406451
# Buying Stock4 at time 686 with -309.0 shares
# Predicted Stock4 return: -0.008061580378243526
# Buying Stock4 at time 687 with -321.0 shares
# Predicted Stock4 return: 0.07765639354362219
# Buying Stock4 at time 688 with 325.0 shares
# Predicted Stock4 return: -0.013506888113514685
# Buying Stock4 at time 689 with -303.0 shares
# Predicted Stock4 return: -0.04793678433744813
# Buying Stock4 at time 690 with -306.0 shares
# Predicted Stock4 return: -0.008902770861750745
# Buying Stock4 at time 691 with -326.0 shares
# Predicted Stock4 return: 0.015468510230163768
# Buying Stock4 at time 692 with 328.0 shares
# Predicted Stock4 return: -0.14797410741061048
# Buying Stock4 at time 693 with -321.0 shares
# Predicted Stock4 return: 0.028549860326222188
# Buying Stock4 at time 694 with 375.0 shares
# Predicted Stock4 return: -0.019871723699351137
# Buying Stock4 at time 695 with -362.0 shares
# Predicted Stock4 return: 0.0020183611777372912
# Buying Stock4 at time 696 with 356.0 shares
# Predicted Stock4 return: 0.019284670604111993
# Buying Stock4 at time 697 with 367.0 shares
# Predicted Stock4 return: 0.050857709080342976
# Buying Stock4 at time 698 with 347.0 shares
# Predicted Stock4 return: -0.018174906512408658
# Buying Stock4 at time 699 with -324.0 shares
# Predicted Stock4 return: -0.07415601543084382
# Buying Stock4 at time 700 with -336.0 shares
# Predicted Stock4 return: -0.03253383269380737
# Buying Stock4 at time 701 with -378.0 shares
# Predicted Stock4 return: 0.03068520285833536
# Buying Stock4 at time 702 with 395.0 shares
# Predicted Stock4 return: -0.002618071716286881
# Buying Stock4 at time 703 with -381.0 shares
# Predicted Stock4 return: -0.06667938131714637
# Buying Stock4 at time 704 with -384.0 shares
# Predicted Stock4 return: -0.13721323332395835
# Buying Stock4 at time 705 with -417.0 shares
# Predicted Stock4 return: 0.0747384996961771
# Buying Stock4 at time 706 with 487.0 shares
# Predicted Stock4 return: -0.16735034146735653
# Buying Stock4 at time 707 with -440.0 shares
# Predicted Stock4 return: 0.03334801128231844
# Buying Stock4 at time 708 with 513.0 shares
# Predicted Stock4 return: -0.10422959250170355
# Buying Stock4 at time 709 with -509.0 shares
# Predicted Stock4 return: -0.047171240097886605
# Buying Stock4 at time 710 with -560.0 shares
# Predicted Stock4 return: -0.003507137360598757
# Buying Stock4 at time 711 with -630.0 shares
# Predicted Stock4 return: -0.039153108951117524
# Buying Stock4 at time 712 with -631.0 shares
# Predicted Stock4 return: -0.13132462214611987
# Buying Stock4 at time 713 with -640.0 shares
# Predicted Stock4 return: 0.02625912120417526
# Buying Stock4 at time 714 with 742.0 shares
# Predicted Stock4 return: 0.03603420560068118
# Buying Stock4 at time 715 with 745.0 shares
# Predicted Stock4 return: -0.0677170772729846
# Buying Stock4 at time 716 with -732.0 shares
# Predicted Stock4 return: -0.03970464589554402
# Buying Stock4 at time 717 with -787.0 shares
# Predicted Stock4 return: -0.061879357513182014
# Buying Stock4 at time 718 with -854.0 shares
# Predicted Stock4 return: 0.0535871353595059
# Buying Stock4 at time 719 with 876.0 shares
# Predicted Stock4 return: 0.0816633675458299
# Buying Stock4 at time 720 with 818.0 shares
# Predicted Stock4 return: -0.12180758868460498
# Buying Stock4 at time 721 with -746.0 shares
# Predicted Stock4 return: 0.044632307216852116
# Buying Stock4 at time 722 with 853.0 shares
# Predicted Stock4 return: -0.03974664569585235
# Buying Stock4 at time 723 with -800.0 shares
# Predicted Stock4 return: 0.11113710222801873
# Buying Stock4 at time 724 with 839.0 shares
# Predicted Stock4 return: 0.03860646773924324
# Buying Stock4 at time 725 with 748.0 shares
# Predicted Stock4 return: 0.20235395368572523
# Buying Stock4 at time 726 with 734.0 shares
# Predicted Stock4 return: 0.032966529205088094
# Buying Stock4 at time 727 with 640.0 shares
# Predicted Stock4 return: 0.04015884594997807
# Buying Stock4 at time 728 with 615.0 shares
# Predicted Stock4 return: -0.0378108167313954
# Buying Stock4 at time 729 with -601.0 shares
# Predicted Stock4 return: 0.00624904502034495
# Buying Stock4 at time 730 with 611.0 shares
# Predicted Stock4 return: -0.10480849629223962
# Buying Stock4 at time 731 with -604.0 shares
# Predicted Stock4 return: 0.06654558192223661
# Buying Stock4 at time 732 with 708.0 shares
# Predicted Stock4 return: 0.13307976175937414
# Buying Stock4 at time 733 with 669.0 shares
# Predicted Stock4 return: -0.008148205491510574
# Buying Stock4 at time 734 with -582.0 shares
# Predicted Stock4 return: -0.04202264224812829
# Buying Stock4 at time 735 with -601.0 shares
# Predicted Stock4 return: -0.08357693244454745
# Buying Stock4 at time 736 with -640.0 shares
# Predicted Stock4 return: 0.003705994897643338
# Buying Stock4 at time 737 with 704.0 shares
# Predicted Stock4 return: -0.046357304387244315
# Buying Stock4 at time 738 with -686.0 shares
# Predicted Stock4 return: 0.030455463286723987
# Buying Stock4 at time 739 with 722.0 shares
# Predicted Stock4 return: 0.07161207766587124
# Buying Stock4 at time 740 with 701.0 shares
# Predicted Stock4 return: 0.06348492906332573
# Buying Stock4 at time 741 with 638.0 shares
# Predicted Stock4 return: 0.025307559687131196
# Buying Stock4 at time 742 with 606.0 shares
# Predicted Stock4 return: -0.008997747590025423
# Buying Stock4 at time 743 with -597.0 shares
# Predicted Stock4 return: -0.008153048525346812
# Buying Stock4 at time 744 with -618.0 shares
# Predicted Stock4 return: 0.041404354756106716
# Buying Stock4 at time 745 with 625.0 shares
# Predicted Stock4 return: -0.028045162721148764
# Buying Stock4 at time 746 with -618.0 shares
# Predicted Stock4 return: -0.10514465934106423
# Buying Stock4 at time 747 with -641.0 shares
# Predicted Stock4 return: -0.015809460180392698
# Buying Stock4 at time 748 with -730.0 shares
# Predicted Stock4 return: 0.0032817269023493814
# Buying Stock4 at time 749 with 741.0 shares
# Predicted Stock4 return: -0.09347538664659699
# Buying Stock4 at time 750 with -744.0 shares
# Predicted Stock4 return: -0.012868511090378856
# Buying Stock4 at time 751 with -826.0 shares
# Predicted Stock4 return: -0.104271593808374
# Buying Stock4 at time 752 with -849.0 shares
# Predicted Stock4 return: -0.04696466318920186
# Buying Stock4 at time 753 with -945.0 shares
# Predicted Stock4 return: 0.03055509936952702
# Buying Stock4 at time 754 with 1001.0 shares
# Predicted Stock4 return: -0.13302791356630012
# Buying Stock4 at time 755 with -990.0 shares
# Predicted Stock4 return: -0.0018406317616440956
# Buying Stock4 at time 756 with -1094.0 shares
# Predicted Stock4 return: 0.07201212459814324
# Buying Stock4 at time 757 with 1088.0 shares
# Predicted Stock4 return: -0.011217428334667965
# Buying Stock4 at time 758 with -992.0 shares
# Predicted Stock4 return: 0.043376574714484584
# Buying Stock4 at time 759 with 968.0 shares
# Predicted Stock4 return: 0.023316786329640248
# Buying Stock4 at time 760 with 910.0 shares
# Predicted Stock4 return: -0.018025595337634502
# Buying Stock4 at time 761 with -892.0 shares
# Predicted Stock4 return: -0.08154923707076203
# Buying Stock4 at time 762 with -935.0 shares
# Predicted Stock4 return: 0.03742921414715402
# Buying Stock4 at time 763 with 1007.0 shares
# Predicted Stock4 return: -0.03298091864856
# Buying Stock4 at time 764 with -974.0 shares
# Predicted Stock4 return: 0.06773722644010083
# Buying Stock4 at time 765 with 1010.0 shares
# Predicted Stock1 return: -0.0005675859543147041
# Buying Stock1 at time 766 with -734.0 shares
# Predicted Stock4 return: 0.01692843853146752
# Buying Stock4 at time 767 with 940.0 shares
# Predicted Stock4 return: 0.12095989629379264
# Buying Stock4 at time 768 with 915.0 shares
# Predicted Stock4 return: -0.0499181839966001
# Buying Stock4 at time 769 with -821.0 shares
# Predicted Stock4 return: 0.03352404039159271
# Buying Stock4 at time 770 with 886.0 shares
# Predicted Stock4 return: -0.015451268452034268
# Buying Stock4 at time 771 with -852.0 shares
# Predicted Stock4 return: 0.08036468383757053
# Buying Stock4 at time 772 with 884.0 shares
# Predicted Stock4 return: 0.11132520041299238
# Buying Stock4 at time 773 with 810.0 shares
# Predicted Stock4 return: 0.016446242351434076
# Buying Stock4 at time 774 with 722.0 shares
# Predicted Stock4 return: -0.03408093974368931
# Buying Stock4 at time 775 with -699.0 shares
# Predicted Stock4 return: -0.03070387840634592
# Buying Stock4 at time 776 with -725.0 shares
# Predicted Stock4 return: -0.03157175068280652
# Buying Stock4 at time 777 with -737.0 shares
# Predicted Stock4 return: 0.021993631236248333
# Buying Stock4 at time 778 with 756.0 shares
# Predicted Stock4 return: -0.0264786403885121
# Buying Stock4 at time 779 with -734.0 shares
# Predicted Stock4 return: 0.05815096646723784
# Buying Stock4 at time 780 with 748.0 shares
# Predicted Stock4 return: 0.007531567121895558
# Buying Stock4 at time 781 with 722.0 shares
# Predicted Stock4 return: 0.08189862833579725
# Buying Stock4 at time 782 with 710.0 shares
# Predicted Stock4 return: -0.0026604697255382566
# Buying Stock4 at time 783 with -642.0 shares
# Predicted Stock4 return: 0.01092239283064976
# Buying Stock4 at time 784 with 647.0 shares
# Predicted Stock4 return: -0.03406824729395755
# Buying Stock4 at time 785 with -632.0 shares
# Predicted Stock4 return: 0.14469872433559414
# Buying Stock4 at time 786 with 670.0 shares
# Predicted Stock4 return: 0.032944456848705894
# Buying Stock4 at time 787 with 581.0 shares
# Predicted Stock4 return: 0.09519422521236223
# Buying Stock4 at time 788 with 565.0 shares
# Predicted Stock4 return: 0.08702810924197912
# Buying Stock4 at time 789 with 519.0 shares
# Predicted Stock4 return: 0.27024928304238705
# Buying Stock4 at time 790 with 478.0 shares
# Predicted Stock4 return: 0.008329986927093625
# Buying Stock4 at time 791 with 365.0 shares
# Predicted Stock4 return: -0.09431038370007278
# Buying Stock4 at time 792 with -361.0 shares
# Predicted Stock4 return: 0.1014419438508109
# Buying Stock4 at time 793 with 403.0 shares
# Predicted Stock4 return: 0.1303189104105343
# Buying Stock4 at time 794 with 357.0 shares
# Predicted Stock4 return: 0.05702022308462912
# Buying Stock4 at time 795 with 316.0 shares
# Predicted Stock4 return: 0.036421043964802884
# Buying Stock4 at time 796 with 303.0 shares
# Predicted Stock4 return: -0.03361413547262071
# Buying Stock4 at time 797 with -291.0 shares
# Predicted Stock4 return: 0.10102741804893148
# Buying Stock4 at time 798 with 297.0 shares
# Predicted Stock4 return: -0.02478317932018231
# Buying Stock4 at time 799 with -272.0 shares
#       Stock1   Stock2   Stock3   Stock4  Stock1_Next  Stock2_Next  \
# 0    1479.36  1088.26  1545.61  1304.27      1479.33      1087.03
# 1    1479.33  1087.03  1544.94  1305.82      1479.72      1087.16
# 2    1479.72  1087.16  1543.55  1287.43      1477.47      1077.92
# 3    1477.47  1077.92  1545.35  1193.67      1474.91      1076.45
# 4    1474.91  1076.45  1545.01  1296.92      1472.41      1074.89
# ..       ...      ...      ...      ...          ...          ...
# 795   785.90   938.11  1548.77  1904.48       786.96       939.40
# 796   786.96   939.40  1549.56  1981.77       787.78       944.30
# 797   787.78   944.30  1548.68  2060.57       787.57       944.60
# 798   787.57   944.60  1551.01  2023.45       788.28       972.23
# 799   788.28   972.23  1550.34  2205.54       788.28       972.23
#
#      Stock3_Next  Stock4_Next  Stock1_Positions  Stock2_Positions  \
# 0        1544.94      1305.82               0.0               0.0
# 1        1543.55      1287.43               0.0               0.0
# 2        1545.35      1193.67               0.0               0.0
# 3        1545.01      1296.92               0.0               0.0
# 4        1544.71      1270.44               0.0               0.0
# ..           ...          ...               ...               ...
# 795      1549.56      1981.77               0.0               0.0
# 796      1548.68      2060.57               0.0               0.0
# 797      1551.01      2023.45               0.0               0.0
# 798      1550.34      2205.54               0.0               0.0
# 799      1550.34      2205.54               0.0               0.0
#
#      Stock3_Positions  Stock4_Positions       Pnl  Stock1_Pnl  Stock2_Pnl  \
# 0                   0               0.0      0.00        -0.0        -0.0
# 1                   0               0.0      0.00         0.0         0.0
# 2                   0            -466.0  43692.16        -0.0        -0.0
# 3                   0             502.0  51831.50        -0.0        -0.0
# 4                   0            -462.0  12233.76        -0.0        -0.0
# ..                ...               ...       ...         ...         ...
# 795                 0             315.0  24346.35         0.0         0.0
# 796                 0             302.0  23797.60         0.0         0.0
# 797                 0            -291.0  10801.92        -0.0         0.0
# 798                 0             296.0  53898.64         0.0         0.0
# 799                 0            -272.0      0.00         0.0         0.0
#
#      Stock3_Pnl  Stock4_Pnl
# 0          -0.0        0.00
# 1          -0.0       -0.00
# 2           0.0    43692.16
# 3          -0.0    51831.50
# 4          -0.0    12233.76
# ..          ...         ...
# 795         0.0    24346.35
# 796        -0.0    23797.60
# 797         0.0    10801.92
# 798        -0.0    53898.64
# 799         0.0       -0.00
#
# [800 rows x 17 columns]

# %%
results.pnl
# Out:
# 25204182.41
